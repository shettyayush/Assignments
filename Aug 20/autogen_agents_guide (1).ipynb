# %% [markdown]
# # AutoGen: Building Conversational Multi-Agent Systems
#
# This notebook is a comprehensive, practical guide to **AutoGen** (Microsoft's framework for building LLM-powered multi-agent conversation systems). AutoGen agents communicate through structured conversations, making it well-suited for iterative, back-and-forth problem solving.
#
# All examples use **GPT-4o-mini** as the language model and **text-embedding-3-small** for embedding operations.
#
# ---
#
# ## Table of Contents
#
# 1. Installation and Environment Setup
# 2. Core Concepts: How AutoGen Differs from CrewAI
# 3. Agent Types and Their Properties
# 4. ConversableAgent Properties Deep Dive
# 5. Conversation Patterns
# 6. Implementation 1 — Two-Agent Code Generation and Review
# 7. Implementation 2 — GroupChat: Multi-Agent Product Planning
# 8. Implementation 3 — Math Tutoring with Code Execution
# 9. Implementation 4 — Automated Data Analysis Pipeline
# 11. Advanced: Tool / Function Calling
# 12. Advanced: Nested Chats
# 13. Advanced: Human Proxy with Termination Conditions
# 14. Advanced: Custom Reply Functions
# 15. Best Practices and Common Pitfalls

# %% [markdown]
# ---
# ## 1. Installation and Environment Setup

# %%
# Install AutoGen and supporting libraries
# %pip install pyautogen openai python-dotenv chromadb sentence-transformers --quiet

# For code execution sandbox support
# %pip install docker --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 50.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.3/119.3 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.9/101.9 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 14.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 75.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 51.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.2/137.2 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.6/204.6 kB 12.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.7/94.7 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 4.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-adk 2.7.0 requires opentelemetry-api<=1.43,>=1.39, but you have opentelemetry-api 1.44.0 which is incompatible.
# google-adk 2.7.0 requires opentelemetry-sdk<=1.43,>=1.39, but you have opentelemetry-sdk 1.44.0 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.8/148.8 kB 4.8 MB/s eta 0:00:00

# %%
# Re-install AutoGen to ensure all dependencies are met
# %pip install pyautogen --quiet

# %%
from google.colab import userdata

# Fetch API key securely from Colab Secrets
api_key = userdata.get("OPENAI_API_KEY")

assert api_key, "OPENAI_API_KEY must be set in Colab Secrets."

# AutoGen config_list
config_list = [
    {
        "model": "gpt-4o-mini",
        "api_key": api_key,
    }
]

# LLM configuration
llm_config = {
    "config_list": config_list,
    "temperature": 0.2,
    "cache_seed": None,  # Set to an int like 42 for reproducibility
}

print("AutoGen environment configured.")
print(f"Model: {config_list[0]['model']}")
# Out:
# AutoGen environment configured.
# Model: gpt-4o-mini

# %% [markdown]
# ---
# ## 2. Core Concepts: How AutoGen Differs from CrewAI
#
# | Aspect | CrewAI | AutoGen |
# |---|---|---|
# | **Paradigm** | Role-based task assignment | Conversational message passing |
# | **Execution** | Tasks run sequentially or hierarchically | Agents converse in turns until termination |
# | **Human interaction** | Optional pause on specific tasks | Central via `HumanProxyAgent` |
# | **Code execution** | External tools only | Native sandboxed code execution |
# | **Multi-agent** | Crew orchestrates agents | GroupChat with a manager routes messages |
# | **Best for** | Structured pipelines with defined outputs | Iterative problem solving requiring dialogue |
#
# ### The AutoGen Conversation Model
#
# In AutoGen, agents communicate by sending and receiving **messages** (strings or dicts). The conversation continues until a **termination condition** is met — typically when an agent sends a message containing a specific string (e.g., `TERMINATE`) or a maximum number of turns is reached.

# %% [markdown]
# ---
# ## 3. Agent Types and Their Properties
#
# AutoGen ships with several agent classes, each suited to different roles:
#
# | Agent Class | Purpose |
# |---|---|
# | `ConversableAgent` | The base class. All agents inherit from this. |
# | `AssistantAgent` | An LLM-backed agent optimized for AI assistance tasks. |
# | `UserProxyAgent` | Simulates a human user. Can execute code locally or in Docker. |
# | `GroupChatManager` | Orchestrates which agent speaks next in a group conversation. |
# | `RetrieveAssistantAgent` | AssistantAgent extended with RAG capabilities. |
# | `RetrieveUserProxyAgent` | UserProxyAgent extended with document retrieval. |

# %%
# !pip install autogen-ext[openai]
# Out:
# Collecting autogen-ext[openai]
#   Downloading autogen_ext-0.7.5-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: autogen-core==0.7.5 in /usr/local/lib/python3.12/dist-packages (from autogen-ext[openai]) (0.7.5)
# Requirement already satisfied: aiofiles in /usr/local/lib/python3.12/dist-packages (from autogen-ext[openai]) (25.1.0)
# Requirement already satisfied: openai>=1.93 in /usr/local/lib/python3.12/dist-packages (from autogen-ext[openai]) (2.54.0)
# Requirement already satisfied: tiktoken>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from autogen-ext[openai]) (0.13.0)
# Requirement already satisfied: jsonref~=1.1.0 in /usr/local/lib/python3.12/dist-packages (from autogen-core==0.7.5->autogen-ext[openai]) (1.1.0)
# Requirement already satisfied: opentelemetry-api>=1.34.1 in /usr/local/lib/python3.12/dist-packages (from autogen-core==0.7.5->autogen-ext[openai]) (1.44.0)
# Requirement already satisfied: pillow>=11.0.0 in /usr/local/lib/python3.12/dist-packages (from autogen-core==0.7.5->autogen-ext[openai]) (11.3.0)
# Requirement already satisfied: protobuf~=5.29.3 in /usr/local/lib/python3.12/dist-packages (from autogen-core==0.7.5->autogen-ext[openai]) (5.29.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.10.0 in /usr/local/lib/python3.12/dist-packages (from autogen-core==0.7.5->autogen-ext[openai]) (2.13.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from autogen-core==0.7.5->autogen-ext[openai]) (4.16.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.93->autogen-ext[openai]) (4.14.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.93->autogen-ext[openai]) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.93->autogen-ext[openai]) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.93->autogen-ext[openai]) (0.16.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai>=1.93->autogen-ext[openai]) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai>=1.93->autogen-ext[openai]) (4.67.3)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from tiktoken>=0.8.0->autogen-ext[openai]) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from tiktoken>=0.8.0->autogen-ext[openai]) (2.32.4)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai>=1.93->autogen-ext[openai]) (3.18)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai>=1.93->autogen-ext[openai]) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai>=1.93->autogen-ext[openai]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.93->autogen-ext[openai]) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.7.5->autogen-ext[openai]) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.7.5->autogen-ext[openai]) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.7.5->autogen-ext[openai]) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->tiktoken>=0.8.0->autogen-ext[openai]) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->tiktoken>=0.8.0->autogen-ext[openai]) (2.5.0)
# Downloading autogen_ext-0.7.5-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.4/331.4 kB 8.7 MB/s eta 0:00:00
# Installing collected packages: autogen-ext
# Successfully installed autogen-ext-0.7.5

# %% [markdown]
# ---
# ## 4. ConversableAgent Properties Deep Dive

# %%
from google.colab import userdata
from autogen_agentchat.agents import AssistantAgent
from autogen_ext.models.openai import OpenAIChatCompletionClient

# Get API key from Colab secrets
api_key = userdata.get("OPENAI_API_KEY")
assert api_key, "Missing OPENAI_API_KEY in Colab Secrets"

# Create model client (NEW way)
model_client = OpenAIChatCompletionClient(
    model="gpt-4o-mini",
    api_key=api_key,
)

# Create agent (UPDATED)
fully_configured = AssistantAgent(
    name="DataScienceExpert",
    system_message=(
        "You are a senior data scientist with expertise in Python, pandas, "
        "scikit-learn, and statistical modeling. "
        "Explain your approach clearly and end your response with TERMINATE."
    ),
    model_client=model_client,
)

print("✅ Agent configured:", fully_configured.name)
# Out:
# ✅ Agent configured: DataScienceExpert

# %% [markdown]
# ### ConversableAgent Property Summary
#
# | Property | Type | Description |
# |---|---|---|
# | `name` | str | Unique agent identifier |
# | `system_message` | str | Persona and behavior instructions |
# | `llm_config` | dict / False | LLM configuration or disabled |
# | `code_execution_config` | dict / False | Enable local or Docker code execution |
# | `human_input_mode` | str | `NEVER`, `ALWAYS`, or `TERMINATE` |
# | `is_termination_msg` | callable | Function to detect conversation end |
# | `max_consecutive_auto_reply` | int | Cap on auto replies before requesting human |
# | `function_map` | dict | Maps tool names to Python callables |
# | `default_auto_reply` | str | Message sent when the agent has nothing to say |

# %% [markdown]
# ---
# ## 5. Conversation Patterns
#
# AutoGen supports several conversation topologies:

# %%
# Pattern overview (not executed — for reference)

patterns = {
    "Two-Agent Chat": {
        "description": "The simplest pattern. One agent initiates, the other responds. "
                       "Back-and-forth until termination.",
        "method": "agent_a.initiate_chat(agent_b, message='...')",
    },
    "Sequential Chat": {
        "description": "A series of two-agent chats where the summary of one "
                       "is passed as context to the next.",
        "method": "agent.initiate_chats([chat_1_config, chat_2_config, ...])",
    },
    "Group Chat": {
        "description": "Multiple agents in one conversation. A GroupChatManager "
                       "decides which agent speaks next using a selection strategy.",
        "method": "GroupChat + GroupChatManager",
    },
    "Nested Chat": {
        "description": "An agent spawns a private sub-conversation with other agents "
                       "and returns the result to the parent conversation.",
        "method": "agent.register_nested_chats([nested_config])",
    },
}

for name, info in patterns.items():
    print(f"Pattern: {name}")
    print(f"  Description : {info['description']}")
    print(f"  Method      : {info['method']}")
    print()
# Out:
# Pattern: Two-Agent Chat
#   Description : The simplest pattern. One agent initiates, the other responds. Back-and-forth until termination.
#   Method      : agent_a.initiate_chat(agent_b, message='...')
#
# Pattern: Sequential Chat
#   Description : A series of two-agent chats where the summary of one is passed as context to the next.
#   Method      : agent.initiate_chats([chat_1_config, chat_2_config, ...])
#
# Pattern: Group Chat
#   Description : Multiple agents in one conversation. A GroupChatManager decides which agent speaks next using a selection strategy.
#   Method      : GroupChat + GroupChatManager
#
# Pattern: Nested Chat
#   Description : An agent spawns a private sub-conversation with other agents and returns the result to the parent conversation.
#   Method      : agent.register_nested_chats([nested_config])

# %% [markdown]
# ---
# ## 6. Implementation 1 — Two-Agent Code Generation and Review
#
# **Scenario:** A software engineer agent writes Python code and a code reviewer agent audits it for bugs, style, and correctness. They iterate until the reviewer approves.

# %%
# ================================
# INSTALL (run once in Colab)
# ================================
# !pip install pyautogen autogen-ext[openai] --upgrade


# ================================
# IMPORTS
# ================================
import asyncio
from google.colab import userdata

from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_ext.models.openai import OpenAIChatCompletionClient


# ================================
# SETUP MODEL CLIENT
# ================================
api_key = userdata.get("OPENAI_API_KEY")
assert api_key, "Missing OPENAI_API_KEY in Colab Secrets"

model_client = OpenAIChatCompletionClient(
    model="gpt-4o-mini",
    api_key=api_key,
)


# ================================
# AGENTS
# ================================

# --- Engineer Agent ---
engineer = AssistantAgent(
    name="SoftwareEngineer",
    system_message=(
        "You are a senior Python engineer. "
        "Write complete, production-ready Python code with type hints, "
        "docstrings, and proper error handling. "
        "Revise code based on reviewer feedback. "
        "When reviewer says APPROVED, reply TERMINATE."
    ),
    model_client=model_client,
)

# --- Reviewer Agent ---
reviewer = AssistantAgent(
    name="CodeReviewer",
    system_message=(
        "You are a principal engineer reviewing Python code. "
        "Check correctness, type hints, docstrings, validation, and PEP8. "
        "If issues exist, clearly list them and request fixes. "
        "If correct, respond EXACTLY with: APPROVED."
    ),
    model_client=model_client,
)


# ================================
# TEAM (replaces initiate_chat)
# ================================
team = RoundRobinGroupChat(
    participants=[reviewer, engineer],
    max_turns=6,
)


# ================================
# TASK
# ================================
task = (
    "Implement a Python class `BankAccount` with:\n"
    "1. Constructor: owner (str), initial_balance (float=0.0)\n"
    "2. Methods: deposit, withdraw, get_balance, transaction_history\n"
    "3. deposit/withdraw must validate amount > 0\n"
    "4. withdraw raises InsufficientFundsError if balance < 0\n"
    "5. All transactions stored with timestamps"
)


# ================================
# RUN (Colab / Jupyter FIX)
# ================================
result = await team.run(task=task)

print("\n✅ Conversation complete\n")

for msg in result.messages:
    print(f"{msg.source}:")
    print(msg.content)
    print("-" * 50)
# Out:
# Requirement already satisfied: pyautogen in /usr/local/lib/python3.12/dist-packages (0.10.0)
# Requirement already satisfied: autogen-ext[openai] in /usr/local/lib/python3.12/dist-packages (0.7.5)
# Requirement already satisfied: autogen-agentchat>=0.6.4 in /usr/local/lib/python3.12/dist-packages (from pyautogen) (0.7.5)
# Requirement already satisfied: autogen-core==0.7.5 in /usr/local/lib/python3.12/dist-packages (from autogen-ext[openai]) (0.7.5)
# Requirement already satisfied: aiofiles in /usr/local/lib/python3.12/dist-packages (from autogen-ext[openai]) (25.1.0)
# Requirement already satisfied: openai>=1.93 in /usr/local/lib/python3.12/dist-packages (from autogen-ext[openai]) (2.54.0)
# Requirement already satisfied: tiktoken>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from autogen-ext[openai]) (0.13.0)
# Requirement already satisfied: jsonref~=1.1.0 in /usr/local/lib/python3.12/dist-packages (from autogen-core==0.7.5->autogen-ext[openai]) (1.1.0)
# Requirement already satisfied: opentelemetry-api>=1.34.1 in /usr/local/lib/python3.12/dist-packages (from autogen-core==0.7.5->autogen-ext[openai]) (1.44.0)
# Requirement already satisfied: pillow>=11.0.0 in /usr/local/lib/python3.12/dist-packages (from autogen-core==0.7.5->autogen-ext[openai]) (11.3.0)
# Requirement already satisfied: protobuf~=5.29.3 in /usr/local/lib/python3.12/dist-packages (from autogen-core==0.7.5->autogen-ext[openai]) (5.29.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.10.0 in /usr/local/lib/python3.12/dist-packages (from autogen-core==0.7.5->autogen-ext[openai]) (2.13.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from autogen-core==0.7.5->autogen-ext[openai]) (4.16.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.93->autogen-ext[openai]) (4.14.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.93->autogen-ext[openai]) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.93->autogen-ext[openai]) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.93->autogen-ext[openai]) (0.16.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai>=1.93->autogen-ext[openai]) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai>=1.93->autogen-ext[openai]) (4.67.3)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from tiktoken>=0.8.0->autogen-ext[openai]) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from tiktoken>=0.8.0->autogen-ext[openai]) (2.32.4)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai>=1.93->autogen-ext[openai]) (3.18)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai>=1.93->autogen-ext[openai]) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai>=1.93->autogen-ext[openai]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.93->autogen-ext[openai]) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.7.5->autogen-ext[openai]) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.7.5->autogen-ext[openai]) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.7.5->autogen-ext[openai]) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->tiktoken>=0.8.0->autogen-ext[openai]) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->tiktoken>=0.8.0->autogen-ext[openai]) (2.5.0)
#
# ✅ Conversation complete
#
# user:
# Implement a Python class `BankAccount` with:
# 1. Constructor: owner (str), initial_balance (float=0.0)
# 2. Methods: deposit, withdraw, get_balance, transaction_history
# 3. deposit/withdraw must validate amount > 0
# 4. withdraw raises InsufficientFundsError if balance < 0
# 5. All transactions stored with timestamps
# --------------------------------------------------
# CodeReviewer:
# The class implementation you provided contains several issues that need to be addressed. Here is the feedback based on the specified criteria:
#
# 1. **Type Annotations**: Ensure that all methods, including the constructor, have proper type hints.
#
# 2. **Docstrings**: Add docstrings to the class and its methods to explain the purpose and usage of each.
#
# 3. **Validation**: In the `deposit` and `withdraw` methods, validate that the amount is greater than 0. The `withdraw` method should also check if there are sufficient funds before proceeding.
#
# 4. **Custom Exception**: Define a custom exception `InsufficientFundsError` for the case when there are insufficient funds for a withdrawal.
#
# 5. **Transaction History**: Ensure that every transaction includes a timestamp and is stored correctly.
#
# 6. **PEP8 Compliance**: Make sure that variable names and method names are in snake_case and that the overall formatting adheres to PEP8 guidelines.
#
# Please make the necessary fixes to your implementation based on the points above.
# --------------------------------------------------
# SoftwareEngineer:
# Here is the revised implementation of the `BankAccount` class based on your feedback. I have added type hints, docstrings, validation for transactions, and implemented a custom exception for insufficient funds.
#
# ```python
# from datetime import datetime
# from typing import List
#
# class InsufficientFundsError(Exception):
#     """Exception raised when attempting to withdraw funds without sufficient balance."""
#     pass
#
# class Transaction:
#     """Class to represent a transaction with a timestamp."""
#
#     def __init__(self, amount: float, transaction_type: str):
#         """
#         Initializes a transaction with the timestamp, amount, and type.
#
#         Args:
#             amount (float): The amount of money involved in the transaction.
#             transaction_type (str): The type of transaction ('deposit' or 'withdraw').
#         """
#         self.timestamp = datetime.now()
#         self.amount = amount
#         self.transaction_type = transaction_type
#
#     def __repr__(self):
#         return f"{self.timestamp.isoformat()}: {self.transaction_type} ${self.amount:.2f}"
#
# class BankAccount:
#     """Class to represent a bank account."""
#
#     def __init__(self, owner: str, initial_balance: float = 0.0):
#         """
#         Initializes a bank account with an owner and an initial balance.
#
#         Args:
#             owner (str): The name of the account owner.
#             initial_balance (float): The initial balance of the account. Default is 0.0.
#         """
#         self.owner = owner
#         self.balance = initial_balance
#         self.transaction_history: List[Transaction] = []
#
#     def deposit(self, amount: float) -> None:
#         """
#         Deposits an amount into the bank account.
#
#         Args:
#             amount (float): The amount to deposit.
#
#         Raises:
#             ValueError: If the deposit amount is less than or equal to 0.
#         """
#         if amount <= 0:
#             raise ValueError("Deposit amount must be greater than zero.")
#
#         self.balance += amount
#         self.transaction_history.append(Transaction(amount, 'deposit'))
#
#     def withdraw(self, amount: float) -> None:
#         """
#         Withdraws an amount from the bank account.
#
#         Args:
#             amount (float): The amount to withdraw.
#
#         Raises:
#             ValueError: If the withdrawal amount is less than or equal to 0.
#             InsufficientFundsError: If there are not enough funds to complete the withdrawal.
#         """
#         if amount <= 0:
#             raise ValueError("Withdrawal amount must be greater than zero.")
#         if amount > self.balance:
#             raise InsufficientFundsError("Insufficient funds for withdrawal.")
#
#         self.balance -= amount
#         self.transaction_history.append(Transaction(amount, 'withdraw'))
#
#     def get_balance(self) -> float:
#         """
#         Returns the current balance of the bank account.
#
#         Returns:
#             float: The current balance.
#         """
#         return self.balance
#
#     def transaction_history(self) -> List[Transaction]:
#         """
#         Returns the transaction history of the bank account.
#
#         Returns:
#             List[Transaction]: A list of all transactions.
#         """
#         return self.transaction_history
# ```
#
# ### Key Features
#
# 1. **Type Hints**: Every method and class member has appropriate type hints.
# 2. **Docstrings**: Each class and method includes a docstring explaining its purpose and parameters.
# 3. **Validation**: The `deposit` and `withdraw` methods validate the transaction amounts and raise exceptions if the conditions are not met.
# 4. **Custom Exception**: The `InsufficientFundsError` is defined for handling insufficient funds in the `withdraw` method.
# 5. **Transaction History**: Each transaction is recorded with a timestamp and stored in a history list.
#
# Please let me know if further adjustments are needed.
# --------------------------------------------------
# CodeReviewer:
# There are a few issues in your revised implementation of the `BankAccount` class that need to be corrected:
#
# 1. **Method Name Conflict**: The method `transaction_history` in the class conflicts with the instance variable `self.transaction_history`. This will lead to unexpected behavior when trying to retrieve transaction history. The method should be renamed to avoid this conflict, perhaps to `get_transaction_history`.
#
# 2. **PEP8 Compliance**: The class and method names are correctly following PEP8, but be cautious about using the same name for variables and methods, as noted above.
#
# 3. **Docstring for `transaction_history` Method**: A method with the same name as an attribute can lead to confusion regarding what it returns. It should clearly indicate that it retrieves a list of transactions rather than serving as a property.
#
# Please correct these issues in your implementation.
# --------------------------------------------------
# SoftwareEngineer:
# Thank you for the feedback. I will correct the method name conflict and ensure all naming conventions adhere to PEP8 guidelines. The method that retrieves the transaction history will be renamed to `get_transaction_history`. Here's the updated implementation:
#
# ```python
# from datetime import datetime
# from typing import List
#
# class InsufficientFundsError(Exception):
#     """Exception raised when attempting to withdraw funds without sufficient balance."""
#     pass
#
# class Transaction:
#     """Class to represent a transaction with a timestamp."""
#
#     def __init__(self, amount: float, transaction_type: str):
#         """
#         Initializes a transaction with the timestamp, amount, and type.
#
#         Args:
#             amount (float): The amount of money involved in the transaction.
#             transaction_type (str): The type of transaction ('deposit' or 'withdraw').
#         """
#         self.timestamp = datetime.now()
#         self.amount = amount
#         self.transaction_type = transaction_type
#
#     def __repr__(self) -> str:
#         return f"{self.timestamp.isoformat()}: {self.transaction_type} ${self.amount:.2f}"
#
# class BankAccount:
#     """Class to represent a bank account."""
#
#     def __init__(self, owner: str, initial_balance: float = 0.0):
#         """
#         Initializes a bank account with an owner and an initial balance.
#
#         Args:
#             owner (str): The name of the account owner.
#             initial_balance (float): The initial balance of the account. Default is 0.0.
#         """
#         self.owner = owner
#         self.balance = initial_balance
#         self._transaction_history: List[Transaction] = []
#
#     def deposit(self, amount: float) -> None:
#         """
#         Deposits an amount into the bank account.
#
#         Args:
#             amount (float): The amount to deposit.
#
#         Raises:
#             ValueError: If the deposit amount is less than or equal to 0.
#         """
#         if amount <= 0:
#             raise ValueError("Deposit amount must be greater than zero.")
#
#         self.balance += amount
#         self._transaction_history.append(Transaction(amount, 'deposit'))
#
#     def withdraw(self, amount: float) -> None:
#         """
#         Withdraws an amount from the bank account.
#
#         Args:
#             amount (float): The amount to withdraw.
#
#         Raises:
#             ValueError: If the withdrawal amount is less than or equal to 0.
#             InsufficientFundsError: If there are not enough funds to complete the withdrawal.
#         """
#         if amount <= 0:
#             raise ValueError("Withdrawal amount must be greater than zero.")
#         if amount > self.balance:
#             raise InsufficientFundsError("Insufficient funds for withdrawal.")
#
#         self.balance -= amount
#         self._transaction_history.append(Transaction(amount, 'withdraw'))
#
#     def get_balance(self) -> float:
#         """
#         Returns the current balance of the bank account.
#
#         Returns:
#             float: The current balance.
#         """
#         return self.balance
#
#     def get_transaction_history(self) -> List[Transaction]:
#         """
#         Returns the transaction history of the bank account.
#
#         Returns:
#             List[Transaction]: A list of all transactions.
#         """
#         return self._transaction_history
# ```
#
# ### Changes Made
# 1. **Renamed Method**: The `transaction_history` method has been renamed to `get_transaction_history` to avoid conflict with the instance variable `_transaction_history`.
# 2. **Private Variable**: Changed `self.transaction_history` to `self._transaction_history` to emphasize that it's an internal state.
#
# Please let me know if there are any more adjustments or if everything is satisfactory.
# --------------------------------------------------
# CodeReviewer:
# APPROVED
# --------------------------------------------------
# SoftwareEngineer:
# TERMINATE
# --------------------------------------------------

# %% [markdown]
# ---
# ## 7. Implementation 2 — GroupChat: Multi-Agent Product Planning
#
# **Scenario:** A product launch is being planned. A Product Manager, UX Designer, Backend Engineer, and Marketing Lead debate requirements in a group chat. A manager routes the conversation.

# %%
# ================================
# INSTALL (run once)
# ================================
# !pip install pyautogen autogen-ext[openai] --upgrade


# ================================
# IMPORTS
# ================================
from google.colab import userdata
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_ext.models.openai import OpenAIChatCompletionClient


# ================================
# MODEL CLIENT
# ================================
api_key = userdata.get("OPENAI_API_KEY")

model_client = OpenAIChatCompletionClient(
    model="gpt-4o-mini",
    api_key=api_key,
)


# ================================
# AGENTS (SPECIALISTS)
# ================================

product_manager = AssistantAgent(
    name="ProductManager",
    system_message=(
        "You are a product manager. Define user stories, acceptance criteria, "
        "and prioritize features. Focus on user value and business impact."
    ),
    model_client=model_client,
)

ux_designer = AssistantAgent(
    name="UXDesigner",
    system_message=(
        "You are a UX designer. Focus on usability, accessibility, and interface design. "
        "Propose clear UX decisions."
    ),
    model_client=model_client,
)

backend_engineer = AssistantAgent(
    name="BackendEngineer",
    system_message=(
        "You are a backend engineer. Evaluate technical feasibility, APIs, scalability, "
        "security, and timelines."
    ),
    model_client=model_client,
)

marketing_lead = AssistantAgent(
    name="MarketingLead",
    system_message=(
        "You are a marketing lead. Focus on go-to-market strategy, messaging, "
        "target audience, and differentiation."
    ),
    model_client=model_client,
)

# Optional: Stakeholder agent (replaces UserProxyAgent)
stakeholder = AssistantAgent(
    name="Stakeholder",
    system_message=(
        "You are the business stakeholder guiding the discussion. "
        "Ensure the team reaches a clear consensus and ends with MEETING ADJOURNED."
    ),
    model_client=model_client,
)


# ================================
# TEAM (REPLACES GROUPCHAT)
# ================================
team = RoundRobinGroupChat(
    participants=[
        stakeholder,
        product_manager,
        ux_designer,
        backend_engineer,
        marketing_lead,
    ],
    max_turns=12,
)


# ================================
# TASK (MEETING AGENDA)
# ================================
task = (
    "We are planning the launch of a B2B SaaS expense management tool "
    "for SMBs (10–200 employees), launching in 90 days.\n\n"
    "Discuss:\n"
    "1. Three must-have MVP features\n"
    "2. Key technical architecture decisions\n"
    "3. Primary go-to-market channel\n"
    "4. Biggest risk to timeline\n\n"
    "Conclude with a consensus summary.\n"
    "End with MEETING ADJOURNED."
)


# ================================
# RUN (Colab-safe)
# ================================
result = await team.run(task=task)

print("\n✅ Meeting complete\n")

for msg in result.messages:
    print(f"{msg.source}:")
    print(msg.content)
    print("-" * 50)
# Out:
# ✅ Meeting complete
#
# user:
# We are planning the launch of a B2B SaaS expense management tool for SMBs (10–200 employees), launching in 90 days.
#
# Discuss:
# 1. Three must-have MVP features
# 2. Key technical architecture decisions
# 3. Primary go-to-market channel
# 4. Biggest risk to timeline
#
# Conclude with a consensus summary.
# End with MEETING ADJOURNED.
# --------------------------------------------------
# Stakeholder:
# Great, let’s dive into the discussion around the launch of our B2B SaaS expense management tool. I’d like us to address each point clearly to reach a consensus.
#
# ### 1. Three Must-Have MVP Features
# To ensure we address the core needs of SMBs, I propose the following three must-have features:
#
# - **Expense Tracking and Reporting**: Users should be able to easily log expenses, categorize them, and generate reports. This feature will facilitate efficient expense management and insight generation.
#
# - **Integration with Banking and Accounting Software**: We need the tool to seamlessly integrate with popular banking and accounting software (like QuickBooks, Xero, etc.) to streamline data entry and reconciliation.
#
# - **Multi-User Access with Role-Based Permissions**: SMBs typically have different team members involved in the expense process, so allowing multiple users with role-based access control will enhance usability and security.
#
# Do we all agree on these features as essential for the MVP?
#
# ### 2. Key Technical Architecture Decisions
# Regarding technical architecture, I suggest we consider the following:
#
# - **Cloud-Based Architecture**: A cloud-native solution will ensure scalability and reduce infrastructure costs. Considering using a modern stack (e.g., Node.js, React for frontend, and cloud databases like AWS or Azure).
#
# - **API-First Approach**: This will allow for easy integration with other tools and facilitate a more modular design as features grow.
#
# - **Data Security Framework**: Given the financial nature of the tool, having a strong security framework from the start is paramount. We should adopt encryption and regular audits.
#
# Is everyone on board with this technical direction?
#
# ### 3. Primary Go-To-Market Channel
# For our initial marketing strategy, I recommend focusing on:
#
# - **Content Marketing & SEO**: Creating informative content that addresses financial pain points for SMBs will help draw in organic traffic. This can be supplemented with targeted online ads.
#
# - **Partnerships with Accounting Firms**: Offering our tool as a recommended resource to accounting firms could create strong leads and endorsements.
#
# - **Social Media & Online Communities**: Engaging with groups on platforms like LinkedIn or industry-specific forums can drive awareness.
#
# Are there any additional thoughts or preferences regarding our go-to-market channel?
#
# ### 4. Biggest Risk to Timeline
# The primary risk to our timeline seems to be:
#
# - **Development Delays**: Depending on the complexity of integrations and building the core features, unforeseen development challenges could push us behind schedule.
#
# To mitigate this risk, regular check-ins and agile methodologies with sprint planning will be essential.
#
# Does this resonate with everyone, or do we identify other potential risks?
#
# ### Consensus Summary
# 1. For the MVP features, we agreed on expense tracking, software integration, and multi-user access.
# 2. The technical architecture will be cloud-based using an API-first approach and a robust data security framework.
# 3. We will primarily focus on content marketing, partnerships with accounting firms, and social media engagement as our go-to marketing channels.
# 4. Our main risk to the timeline will come from potential development delays, which we plan to manage through disciplined project management practices.
#
# If everyone is in agreement with these points, then we can consider this meeting concluded.
#
# **MEETING ADJOURNED.**
# --------------------------------------------------
# ProductManager:
# ### Summary Meeting Notes
#
# **Participants:**
# - Stakeholders in the B2B SaaS expense management tool project
#
# **1. Three Must-Have MVP Features**
#    - **Expense Tracking and Reporting**: Essential for users to log, categorize, and report expenses effectively.
#    - **Integration with Banking and Accounting Software**: To streamline data entry and reconciliation among popular platforms like QuickBooks and Xero.
#    - **Multi-User Access with Role-Based Permissions**: To accommodate multiple team members involved in expense management while ensuring security.
#
# **Consensus**: All agreed these features are crucial for the MVP.
#
# ---
#
# **2. Key Technical Architecture Decisions**
#    - **Cloud-Based Architecture**: Choosing a cloud-native solution for scalability and cost-effectiveness, possibly using Node.js and React stack with cloud databases like AWS or Azure.
#    - **API-First Approach**: Enhancing modular design and facilitating easy integration with other tools.
#    - **Data Security Framework**: Implementing robust encryption and regular security audits from the beginning.
#
# **Consensus**: Stakeholders agreed on this technical direction.
#
# ---
#
# **3. Primary Go-To-Market Channel**
#    - **Content Marketing & SEO**: To attract organic traffic by addressing financial pain points relevant to SMBs.
#    - **Partnerships with Accounting Firms**: Positioning the tool as a go-to resource recommended by accounting professionals to generate leads.
#    - **Social Media & Online Communities**: Engaging potential users through platforms like LinkedIn and relevant industry forums.
#
# **Consensus**: The marketing strategy is widely supported, focusing on these channels.
#
# ---
#
# **4. Biggest Risk to Timeline**
#    - **Development Delays**: Recognizing the potential for challenges in building the core features and integrations that could impede progress. Regular agile check-ins and sprint planning suggested to mitigate this risk.
#
# **Consensus**: Acknowledging development delays as the primary risk to the timeline seems to resonate with the stakeholders, along with agreed strategies for management.
#
# ---
#
# ### Conclusion
# Overall, we have reached a consensus on our MVP features, technical architecture, go-to-market strategy, and identified risks. We will continue to collaborate closely over the next 90 days to ensure successful execution ahead of the launch.
#
# **MEETING ADJOURNED.**
# --------------------------------------------------
# UXDesigner:
# ### Summary Meeting Notes
#
# **Participants:**
# - Stakeholders in the B2B SaaS expense management tool project
#
# ---
#
# **1. Three Must-Have MVP Features**
#    - **Expense Tracking and Reporting**: Essential for users to log, categorize, and report expenses effectively.
#    - **Integration with Banking and Accounting Software**: To streamline data entry and reconciliation among popular platforms like QuickBooks and Xero.
#    - **Multi-User Access with Role-Based Permissions**: To accommodate multiple team members involved in expense management while ensuring security.
#
# **Consensus**: All agreed that these features are crucial for the MVP.
#
# ---
#
# **2. Key Technical Architecture Decisions**
#    - **Cloud-Based Architecture**: Choosing a cloud-native solution for scalability and cost-effectiveness, potentially using Node.js and React stack with cloud databases like AWS or Azure.
#    - **API-First Approach**: Enhancing modular design and facilitating easy integration with other tools.
#    - **Data Security Framework**: Implementing robust encryption and regular security audits from the beginning.
#
# **Consensus**: Stakeholders agreed on this technical direction.
#
# ---
#
# **3. Primary Go-To-Market Channel**
#    - **Content Marketing & SEO**: To attract organic traffic by addressing financial pain points relevant to SMBs.
#    - **Partnerships with Accounting Firms**: Positioning the tool as a go-to resource recommended by accounting professionals to generate leads.
#    - **Social Media & Online Communities**: Engaging potential users through platforms like LinkedIn and relevant industry forums.
#
# **Consensus**: The marketing strategy is widely supported, focusing on these channels.
#
# ---
#
# **4. Biggest Risk to Timeline**
#    - **Development Delays**: Recognizing the potential for challenges in building the core features and integrations that could impede progress. Regular agile check-ins and sprint planning were suggested to mitigate this risk.
#
# **Consensus**: Acknowledging development delays as the primary risk to the timeline resonates with stakeholders, along with agreed strategies for management.
#
# ---
#
# ### Conclusion
# Overall, we have reached a consensus on our MVP features, technical architecture, go-to-market strategy, and identified risks. We will continue to collaborate closely over the next 90 days to ensure successful execution ahead of the launch.
#
# **MEETING ADJOURNED.**
# --------------------------------------------------
# BackendEngineer:
# ### Summary Meeting Notes
#
# **Participants:**
# - Stakeholders in the B2B SaaS expense management tool project
#
# ---
#
# **1. Three Must-Have MVP Features**
#    - **Expense Tracking and Reporting**: Essential for users to log, categorize, and report expenses effectively.
#    - **Integration with Banking and Accounting Software**: To streamline data entry and reconciliation among popular platforms like QuickBooks and Xero.
#    - **Multi-User Access with Role-Based Permissions**: To accommodate multiple team members involved in expense management while ensuring security.
#
# **Consensus**: All agreed that these features are crucial for the MVP.
#
# ---
#
# **2. Key Technical Architecture Decisions**
#    - **Cloud-Based Architecture**: Choosing a cloud-native solution for scalability and cost-effectiveness, potentially using Node.js and React stack with cloud databases like AWS or Azure.
#    - **API-First Approach**: Enhancing modular design and facilitating easy integration with other tools.
#    - **Data Security Framework**: Implementing robust encryption and regular security audits from the beginning.
#
# **Consensus**: Stakeholders agreed on this technical direction.
#
# ---
#
# **3. Primary Go-To-Market Channel**
#    - **Content Marketing & SEO**: To attract organic traffic by addressing financial pain points relevant to SMBs.
#    - **Partnerships with Accounting Firms**: Positioning the tool as a go-to resource recommended by accounting professionals to generate leads.
#    - **Social Media & Online Communities**: Engaging potential users through platforms like LinkedIn and relevant industry forums.
#
# **Consensus**: The marketing strategy is widely supported, focusing on these channels.
#
# ---
#
# **4. Biggest Risk to Timeline**
#    - **Development Delays**: Recognizing the potential for challenges in building the core features and integrations that could impede progress. Regular agile check-ins and sprint planning were suggested to mitigate this risk.
#
# **Consensus**: Acknowledging development delays as the primary risk to the timeline resonates with stakeholders, along with agreed strategies for management.
#
# ---
#
# ### Conclusion
# Overall, we have reached a consensus on our MVP features, technical architecture, go-to-market strategy, and identified risks. We will continue to collaborate closely over the next 90 days to ensure successful execution ahead of the launch.
#
# **MEETING ADJOURNED.**
# --------------------------------------------------
# MarketingLead:
# ### Summary Meeting Notes
#
# **Participants:**
# - Stakeholders in the B2B SaaS expense management tool project
#
# ---
#
# **1. Three Must-Have MVP Features**
#    - **Expense Tracking and Reporting**: Essential for users to log, categorize, and report expenses effectively.
#    - **Integration with Banking and Accounting Software**: To streamline data entry and reconciliation among popular platforms like QuickBooks and Xero.
#    - **Multi-User Access with Role-Based Permissions**: To accommodate multiple team members involved in expense management while ensuring security.
#
# **Consensus**: All agreed that these features are crucial for the MVP.
#
# ---
#
# **2. Key Technical Architecture Decisions**
#    - **Cloud-Based Architecture**: Choosing a cloud-native solution for scalability and cost-effectiveness, potentially using Node.js and React stack with cloud databases like AWS or Azure.
#    - **API-First Approach**: Enhancing modular design and facilitating easy integration with other tools.
#    - **Data Security Framework**: Implementing robust encryption and regular security audits from the beginning.
#
# **Consensus**: Stakeholders agreed on this technical direction.
#
# ---
#
# **3. Primary Go-To-Market Channel**
#    - **Content Marketing & SEO**: To attract organic traffic by addressing financial pain points relevant to SMBs.
#    - **Partnerships with Accounting Firms**: Positioning the tool as a go-to resource recommended by accounting professionals to generate leads.
#    - **Social Media & Online Communities**: Engaging potential users through platforms like LinkedIn and relevant industry forums.
#
# **Consensus**: The marketing strategy is widely supported, focusing on these channels.
#
# ---
#
# **4. Biggest Risk to Timeline**
#    - **Development Delays**: Recognizing the potential for challenges in building the core features and integrations that could impede progress. Regular agile check-ins and sprint planning were suggested to mitigate this risk.
#
# **Consensus**: Acknowledging development delays as the primary risk to the timeline resonates with stakeholders, along with agreed strategies for management.
#
# ---
#
# ### Conclusion
# Overall, we have reached a consensus on our MVP features, technical architecture, go-to-market strategy, and identified risks. We will continue to collaborate closely over the next 90 days to ensure successful execution ahead of the launch.
#
# **MEETING ADJOURNED.**
# --------------------------------------------------
# Stakeholder:
# Thank you, everyone, for your contributions and insights during our discussion. Below is the summary of our meeting notes, reinforcing the consensus reached:
#
# ### Summary Meeting Notes
#
# **Participants:**
# - Stakeholders in the B2B SaaS expense management tool project
#
# ---
#
# **1. Three Must-Have MVP Features**
#    - **Expense Tracking and Reporting**: Essential for users to log, categorize, and report expenses effectively.
#    - **Integration with Banking and Accounting Software**: To streamline data entry and reconciliation among popular platforms like QuickBooks and Xero.
#    - **Multi-User Access with Role-Based Permissions**: To accommodate multiple team members involved in expense management while ensuring security.
#
# **Consensus**: All agreed that these features are crucial for the MVP.
#
# ---
#
# **2. Key Technical Architecture Decisions**
#    - **Cloud-Based Architecture**: Choosing a cloud-native solution for scalability and cost-effectiveness, potentially using Node.js and React stack with cloud databases like AWS or Azure.
#    - **API-First Approach**: Enhancing modular design and facilitating easy integration with other tools.
#    - **Data Security Framework**: Implementing robust encryption and regular security audits from the beginning.
#
# **Consensus**: Stakeholders agreed on this technical direction.
#
# ---
#
# **3. Primary Go-To-Market Channel**
#    - **Content Marketing & SEO**: To attract organic traffic by addressing financial pain points relevant to SMBs.
#    - **Partnerships with Accounting Firms**: Positioning the tool as a go-to resource recommended by accounting professionals to generate leads.
#    - **Social Media & Online Communities**: Engaging potential users through platforms like LinkedIn and relevant industry forums.
#
# **Consensus**: The marketing strategy is widely supported, focusing on these channels.
#
# ---
#
# **4. Biggest Risk to Timeline**
#    - **Development Delays**: Recognizing the potential for challenges in building the core features and integrations that could impede progress. Regular agile check-ins and sprint planning were suggested to mitigate this risk.
#
# **Consensus**: Acknowledging development delays as the primary risk to the timeline resonates with stakeholders, along with agreed strategies for management.
#
# ---
#
# ### Conclusion
# Overall, we have reached a consensus on our MVP features, technical architecture, go-to-market strategy, and identified risks. We will continue to collaborate closely over the next 90 days to ensure successful execution ahead of the launch.
#
# Thank you all for your participation and valuable input.
#
# **MEETING ADJOURNED.**
# --------------------------------------------------
# ProductManager:
# ### Summary Meeting Notes
#
# **Participants:**
# - Stakeholders in the B2B SaaS expense management tool project
#
# ---
#
# **1. Three Must-Have MVP Features**
#    - **Expense Tracking and Reporting**: Essential for users to log, categorize, and report expenses effectively.
#    - **Integration with Banking and Accounting Software**: To streamline data entry and reconciliation among popular platforms like QuickBooks and Xero.
#    - **Multi-User Access with Role-Based Permissions**: To accommodate multiple team members involved in expense management while ensuring security.
#
# **Consensus**: All agreed that these features are crucial for the MVP.
#
# ---
#
# **2. Key Technical Architecture Decisions**
#    - **Cloud-Based Architecture**: Choosing a cloud-native solution for scalability and cost-effectiveness, potentially using Node.js and React stack with cloud databases like AWS or Azure.
#    - **API-First Approach**: Enhancing modular design and facilitating easy integration with other tools.
#    - **Data Security Framework**: Implementing robust encryption and regular security audits from the beginning.
#
# **Consensus**: Stakeholders agreed on this technical direction.
#
# ---
#
# **3. Primary Go-To-Market Channel**
#    - **Content Marketing & SEO**: To attract organic traffic by addressing financial pain points relevant to SMBs.
#    - **Partnerships with Accounting Firms**: Positioning the tool as a go-to resource recommended by accounting professionals to generate leads.
#    - **Social Media & Online Communities**: Engaging potential users through platforms like LinkedIn and relevant industry forums.
#
# **Consensus**: The marketing strategy is widely supported, focusing on these channels.
#
# ---
#
# **4. Biggest Risk to Timeline**
#    - **Development Delays**: Recognizing the potential for challenges in building the core features and integrations that could impede progress. Regular agile check-ins and sprint planning were suggested to mitigate this risk.
#
# **Consensus**: Acknowledging development delays as the primary risk to the timeline resonates with stakeholders, along with agreed strategies for management.
#
# ---
#
# ### Conclusion
# Overall, we have reached a consensus on our MVP features, technical architecture, go-to-market strategy, and identified risks. We will continue to collaborate closely over the next 90 days to ensure successful execution ahead of the launch.
#
# Thank you all for your participation and valuable input.
#
# **MEETING ADJOURNED.**
# --------------------------------------------------
# UXDesigner:
# ### Summary Meeting Notes
#
# **Participants:**
# - Stakeholders in the B2B SaaS expense management tool project
#
# ---
#
# **1. Three Must-Have MVP Features**
#    - **Expense Tracking and Reporting**: Essential for users to log, categorize, and report expenses effectively.
#    - **Integration with Banking and Accounting Software**: To streamline data entry and reconciliation among popular platforms like QuickBooks and Xero.
#    - **Multi-User Access with Role-Based Permissions**: To accommodate multiple team members involved in expense management while ensuring security.
#
# **Consensus**: All agreed that these features are crucial for the MVP.
#
# ---
#
# **2. Key Technical Architecture Decisions**
#    - **Cloud-Based Architecture**: Choosing a cloud-native solution for scalability and cost-effectiveness, potentially using Node.js and React stack with cloud databases like AWS or Azure.
#    - **API-First Approach**: Enhancing modular design and facilitating easy integration with other tools.
#    - **Data Security Framework**: Implementing robust encryption and regular security audits from the beginning.
#
# **Consensus**: Stakeholders agreed on this technical direction.
#
# ---
#
# **3. Primary Go-To-Market Channel**
#    - **Content Marketing & SEO**: To attract organic traffic by addressing financial pain points relevant to SMBs.
#    - **Partnerships with Accounting Firms**: Positioning the tool as a go-to resource recommended by accounting professionals to generate leads.
#    - **Social Media & Online Communities**: Engaging potential users through platforms like LinkedIn and relevant industry forums.
#
# **Consensus**: The marketing strategy is widely supported, focusing on these channels.
#
# ---
#
# **4. Biggest Risk to Timeline**
#    - **Development Delays**: Recognizing the potential for challenges in building the core features and integrations that could impede progress. Regular agile check-ins and sprint planning were suggested to mitigate this risk.
#
# **Consensus**: Acknowledging development delays as the primary risk to the timeline resonates with stakeholders, along with agreed strategies for management.
#
# ---
#
# ### Conclusion
# Overall, we have reached a consensus on our MVP features, technical architecture, go-to-market strategy, and identified risks. We will continue to collaborate closely over the next 90 days to ensure successful execution ahead of the launch.
#
# Thank you all for your participation and valuable input.
#
# **MEETING ADJOURNED.**
# --------------------------------------------------
# BackendEngineer:
# ### Summary Meeting Notes
#
# **Participants:**
# - Stakeholders in the B2B SaaS expense management tool project
#
# ---
#
# **1. Three Must-Have MVP Features**
#    - **Expense Tracking and Reporting**: Essential for users to log, categorize, and report expenses effectively.
#    - **Integration with Banking and Accounting Software**: To streamline data entry and reconciliation among popular platforms like QuickBooks and Xero.
#    - **Multi-User Access with Role-Based Permissions**: To accommodate multiple team members involved in expense management while ensuring security.
#
# **Consensus**: All agreed that these features are crucial for the MVP.
#
# ---
#
# **2. Key Technical Architecture Decisions**
#    - **Cloud-Based Architecture**: Choosing a cloud-native solution for scalability and cost-effectiveness, potentially using Node.js and React stack with cloud databases like AWS or Azure.
#    - **API-First Approach**: Enhancing modular design and facilitating easy integration with other tools.
#    - **Data Security Framework**: Implementing robust encryption and regular security audits from the beginning.
#
# **Consensus**: Stakeholders agreed on this technical direction.
#
# ---
#
# **3. Primary Go-To-Market Channel**
#    - **Content Marketing & SEO**: To attract organic traffic by addressing financial pain points relevant to SMBs.
#    - **Partnerships with Accounting Firms**: Positioning the tool as a go-to resource recommended by accounting professionals to generate leads.
#    - **Social Media & Online Communities**: Engaging potential users through platforms like LinkedIn and relevant industry forums.
#
# **Consensus**: The marketing strategy is widely supported, focusing on these channels.
#
# ---
#
# **4. Biggest Risk to Timeline**
#    - **Development Delays**: Recognizing the potential for challenges in building the core features and integrations that could impede progress. Regular agile check-ins and sprint planning were suggested to mitigate this risk.
#
# **Consensus**: Acknowledging development delays as the primary risk to the timeline resonates with stakeholders, along with agreed strategies for management.
#
# ---
#
# ### Conclusion
# Overall, we have reached a consensus on our MVP features, technical architecture, go-to-market strategy, and identified risks. We will continue to collaborate closely over the next 90 days to ensure successful execution ahead of the launch.
#
# Thank you all for your participation and valuable input.
#
# **MEETING ADJOURNED.**
# --------------------------------------------------
# MarketingLead:
# ### Summary Meeting Notes
#
# **Participants:**
# - Stakeholders in the B2B SaaS expense management tool project
#
# ---
#
# **1. Three Must-Have MVP Features**
#    - **Expense Tracking and Reporting**: Essential for users to log, categorize, and report expenses effectively.
#    - **Integration with Banking and Accounting Software**: To streamline data entry and reconciliation among popular platforms like QuickBooks and Xero.
#    - **Multi-User Access with Role-Based Permissions**: To accommodate multiple team members involved in expense management while ensuring security.
#
# **Consensus**: All agreed that these features are crucial for the MVP.
#
# ---
#
# **2. Key Technical Architecture Decisions**
#    - **Cloud-Based Architecture**: Choosing a cloud-native solution for scalability and cost-effectiveness, potentially using Node.js and React stack with cloud databases like AWS or Azure.
#    - **API-First Approach**: Enhancing modular design and facilitating easy integration with other tools.
#    - **Data Security Framework**: Implementing robust encryption and regular security audits from the beginning.
#
# **Consensus**: Stakeholders agreed on this technical direction.
#
# ---
#
# **3. Primary Go-To-Market Channel**
#    - **Content Marketing & SEO**: To attract organic traffic by addressing financial pain points relevant to SMBs.
#    - **Partnerships with Accounting Firms**: Positioning the tool as a go-to resource recommended by accounting professionals to generate leads.
#    - **Social Media & Online Communities**: Engaging potential users through platforms like LinkedIn and relevant industry forums.
#
# **Consensus**: The marketing strategy is widely supported, focusing on these channels.
#
# ---
#
# **4. Biggest Risk to Timeline**
#    - **Development Delays**: Recognizing the potential for challenges in building the core features and integrations that could impede progress. Regular agile check-ins and sprint planning were suggested to mitigate this risk.
#
# **Consensus**: Acknowledging development delays as the primary risk to the timeline resonates with stakeholders, along with agreed strategies for management.
#
# ---
#
# ### Conclusion
# Overall, we have reached a consensus on our MVP features, technical architecture, go-to-market strategy, and identified risks. We will continue to collaborate closely over the next 90 days to ensure successful execution ahead of the launch.
#
# Thank you all for your participation and valuable input.
#
# **MEETING ADJOURNED.**
# --------------------------------------------------
# Stakeholder:
# Thank you, everyone, for your thorough contributions and active participation in yesterday's meeting regarding the B2B SaaS expense management tool initiative. Here’s a finalized summary of the meeting notes, encapsulating our key discussions and agreements:
#
# ### Summary Meeting Notes
#
# **Participants:**
# - Stakeholders in the B2B SaaS expense management tool project
#
# ---
#
# **1. Three Must-Have MVP Features**
#    - **Expense Tracking and Reporting**: Users must be able to log, categorize, and produce reports on expenses efficiently.
#    - **Integration with Banking and Accounting Software**: This will ease data entry and reconciliation with popular platforms such as QuickBooks and Xero.
#    - **Multi-User Access with Role-Based Permissions**: Essential for allowing multiple team members to be involved in expense management while maintaining required security levels.
#
# **Consensus**: All members agreed that these features are critical for the MVP.
#
# ---
#
# **2. Key Technical Architecture Decisions**
#    - **Cloud-Based Architecture**: Selecting a cloud-native solution for scalability and cost efficiency, possibly utilizing a stack of Node.js and React along with cloud databases such as AWS or Azure.
#    - **API-First Approach**: This approach will improve modular design and simplify integration with other tools.
#    - **Data Security Framework**: Establishing strong data encryption and conducting regular security audits from the outset.
#
# **Consensus**: Stakeholders reached agreement on this technical direction.
#
# ---
#
# **3. Primary Go-To-Market Channel**
#    - **Content Marketing & SEO**: Aiming to capture organic traffic by addressing the financial pain points faced by SMBs.
#    - **Partnerships with Accounting Firms**: Positioning the expense management tool as a recommended resource by accounting professionals to drive leads.
#    - **Social Media & Online Communities**: Actively engaging with potential users on platforms such as LinkedIn and relevant online forums.
#
# **Consensus**: The proposed marketing strategy received unanimous support, emphasizing these channels.
#
# ---
#
# **4. Biggest Risk to Timeline**
#    - **Development Delays**: Acknowledging potential challenges in developing core features and integrations that may hinder progress. It was suggested that regular agile check-ins and sprint planning could mitigate this risk.
#
# **Consensus**: Recognition of development delays as the key risk to our timeline was widely agreed upon, along with strategies to manage it.
#
# ---
#
# ### Conclusion
# We have effectively reached a consensus on the MVP features, technical architecture, go-to-market strategy, and identified risks. Our collaborative effort over the next 90 days is essential for successful execution ahead of the launch.
#
# Thank you all for your valuable input and commitment to this project.
#
# **MEETING ADJOURNED.**
# --------------------------------------------------
# ProductManager:
# ### Finalized Summary Meeting Notes
#
# **Participants:**
# - Stakeholders in the B2B SaaS expense management tool project
#
# ---
#
# **1. Three Must-Have MVP Features**
#    - **Expense Tracking and Reporting**: Users must be able to log, categorize, and produce reports on expenses efficiently.
#    - **Integration with Banking and Accounting Software**: This will ease data entry and reconciliation with popular platforms such as QuickBooks and Xero.
#    - **Multi-User Access with Role-Based Permissions**: Essential for allowing multiple team members to be involved in expense management while maintaining necessary security levels.
#
# **Consensus**: All members agreed that these features are critical for the MVP.
#
# ---
#
# **2. Key Technical Architecture Decisions**
#    - **Cloud-Based Architecture**: Selecting a cloud-native solution for scalability and cost efficiency, possibly utilizing a stack of Node.js and React along with cloud databases such as AWS or Azure.
#    - **API-First Approach**: This approach will improve modular design and simplify integration with other tools.
#    - **Data Security Framework**: Establishing strong data encryption and conducting regular security audits from the outset.
#
# **Consensus**: Stakeholders reached agreement on this technical direction.
#
# ---
#
# **3. Primary Go-To-Market Channel**
#    - **Content Marketing & SEO**: Aiming to capture organic traffic by addressing the financial pain points faced by SMBs.
#    - **Partnerships with Accounting Firms**: Positioning the expense management tool as a recommended resource by accounting professionals to drive leads.
#    - **Social Media & Online Communities**: Actively engaging with potential users on platforms such as LinkedIn and relevant online forums.
#
# **Consensus**: The proposed marketing strategy received unanimous support, emphasizing these channels.
#
# ---
#
# **4. Biggest Risk to Timeline**
#    - **Development Delays**: Acknowledging potential challenges in developing core features and integrations that may hinder progress. It was suggested that regular agile check-ins and sprint planning could mitigate this risk.
#
# **Consensus**: Recognition of development delays as the key risk to our timeline was widely agreed upon, along with strategies to manage it.
#
# ---
#
# ### Conclusion
# We have effectively reached a consensus on the MVP features, technical architecture, go-to-market strategy, and identified risks. Our collaborative effort over the next 90 days is essential for successful execution ahead of the launch.
#
# Thank you all for your valuable input and commitment to this project.
#
# **MEETING ADJOURNED.**
# --------------------------------------------------

# %% [markdown]
# ---
# ## 8. Implementation 3 — Math Tutoring with Code Execution
#
# **Scenario:** A student agent poses a statistics problem. An AI tutor explains the approach and writes Python code. The UserProxyAgent executes the code and returns the result.

# %%
from autogen_ext.code_executors.local import LocalCommandLineCodeExecutor

# %%
# !pip install asyncio-atexit
# Out:
# Collecting asyncio-atexit
#   Downloading asyncio_atexit-1.0.1-py3-none-any.whl.metadata (1.5 kB)
# Downloading asyncio_atexit-1.0.1-py3-none-any.whl (3.8 kB)
# Installing collected packages: asyncio-atexit
# Successfully installed asyncio-atexit-1.0.1

# %%
# ================================
# INSTALL (run once)
# ================================
# !pip install pyautogen autogen-ext[openai] autogen-ext[code] --upgrade


# ================================
# IMPORTS
# ================================
import os
from google.colab import userdata

from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_ext.models.openai import OpenAIChatCompletionClient

# 🔥 NEW IMPORTS
from autogen_ext.code_executors.local import LocalCommandLineCodeExecutor
from autogen_ext.tools.code_execution import PythonCodeExecutionTool


# ================================
# WORKSPACE
# ================================
os.makedirs("./autogen_workspace", exist_ok=True)


# ================================
# MODEL CLIENT
# ================================
api_key = userdata.get("OPENAI_API_KEY")

model_client = OpenAIChatCompletionClient(
    model="gpt-4o-mini",
    api_key=api_key,
)


# ================================
# EXECUTOR (NEW REQUIRED LAYER)
# ================================
executor_backend = LocalCommandLineCodeExecutor(
    work_dir="./autogen_workspace",
    timeout=30,
)


# ================================
# TOOL (WRAPS EXECUTOR)
# ================================
code_tool = PythonCodeExecutionTool(
    executor=executor_backend
)


# ================================
# AGENTS
# ================================
tutor = AssistantAgent(
    name="StatisticsTutor",
    system_message=(
        "You are an expert statistics professor.\n"
        "1. Explain concept\n"
        "2. Write Python code (numpy, scipy, matplotlib)\n"
        "3. Interpret results\n"
        "Wrap code in ONE python block.\n"
        "End with TERMINATE."
    ),
    model_client=model_client,
)

executor_agent = AssistantAgent(
    name="CodeExecutor",
    system_message="Execute Python code and return ONLY output.",
    model_client=model_client,
    tools=[code_tool],
)


# ================================
# TEAM
# ================================
team = RoundRobinGroupChat(
    participants=[tutor, executor_agent],
    max_turns=8,
)


# ================================
# TASK
# ================================
task = (
    "Section A: [72, 85, 90, 68, 77, 95, 82, 78, 88, 74]\n"
    "Section B: [65, 70, 88, 92, 76, 81, 69, 83, 79, 95]\n\n"
    "1. Statistical significance test (alpha=0.05)\n"
    "2. Cohen's d\n"
    "3. Boxplot"
)


# ================================
# RUN (Colab-safe)
# ================================
result = await team.run(task=task)

print("\n✅ Done\n")

for msg in result.messages:
    print(f"{msg.source}:")
    print(msg.content)
    print("-" * 50)
# Out:
# Requirement already satisfied: pyautogen in /usr/local/lib/python3.12/dist-packages (0.10.0)
# Requirement already satisfied: autogen-ext[openai] in /usr/local/lib/python3.12/dist-packages (0.7.5)
# Requirement already satisfied: autogen-agentchat>=0.6.4 in /usr/local/lib/python3.12/dist-packages (from pyautogen) (0.7.5)
# Requirement already satisfied: autogen-core==0.7.5 in /usr/local/lib/python3.12/dist-packages (from autogen-ext[openai]) (0.7.5)
# Requirement already satisfied: aiofiles in /usr/local/lib/python3.12/dist-packages (from autogen-ext[openai]) (24.1.0)
# Requirement already satisfied: openai>=1.93 in /usr/local/lib/python3.12/dist-packages (from autogen-ext[openai]) (2.34.0)
# Requirement already satisfied: tiktoken>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from autogen-ext[openai]) (0.12.0)
# Requirement already satisfied: jsonref~=1.1.0 in /usr/local/lib/python3.12/dist-packages (from autogen-core==0.7.5->autogen-ext[openai]) (1.1.0)
# Requirement already satisfied: opentelemetry-api>=1.34.1 in /usr/local/lib/python3.12/dist-packages (from autogen-core==0.7.5->autogen-ext[openai]) (1.41.1)
# Requirement already satisfied: pillow>=11.0.0 in /usr/local/lib/python3.12/dist-packages (from autogen-core==0.7.5->autogen-ext[openai]) (11.3.0)
# Requirement already satisfied: protobuf~=5.29.3 in /usr/local/lib/python3.12/dist-packages (from autogen-core==0.7.5->autogen-ext[openai]) (5.29.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.10.0 in /usr/local/lib/python3.12/dist-packages (from autogen-core==0.7.5->autogen-ext[openai]) (2.12.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from autogen-core==0.7.5->autogen-ext[openai]) (4.15.0)
# WARNING: autogen-ext 0.7.5 does not provide the extra 'code'
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.93->autogen-ext[openai]) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.93->autogen-ext[openai]) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.93->autogen-ext[openai]) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.93->autogen-ext[openai]) (0.14.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai>=1.93->autogen-ext[openai]) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai>=1.93->autogen-ext[openai]) (4.67.3)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken>=0.8.0->autogen-ext[openai]) (2025.11.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from tiktoken>=0.8.0->autogen-ext[openai]) (2.32.4)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai>=1.93->autogen-ext[openai]) (3.13)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai>=1.93->autogen-ext[openai]) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai>=1.93->autogen-ext[openai]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.93->autogen-ext[openai]) (0.16.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-api>=1.34.1->autogen-core==0.7.5->autogen-ext[openai]) (8.7.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.7.5->autogen-ext[openai]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.7.5->autogen-ext[openai]) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.7.5->autogen-ext[openai]) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken>=0.8.0->autogen-ext[openai]) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken>=0.8.0->autogen-ext[openai]) (2.5.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.34.1->autogen-core==0.7.5->autogen-ext[openai]) (3.23.1)
# /tmp/ipykernel_10701/4018394800.py:42: UserWarning: Using LocalCommandLineCodeExecutor may execute code on the local machine which can be unsafe. For security, it is recommended to use DockerCommandLineCodeExecutor instead. To install Docker, visit: https://docs.docker.com/get-docker/
#   executor_backend = LocalCommandLineCodeExecutor(
# ✅ Done
#
# user:
# Section A: [72, 85, 90, 68, 77, 95, 82, 78, 88, 74]
# Section B: [65, 70, 88, 92, 76, 81, 69, 83, 79, 95]
#
# 1. Statistical significance test (alpha=0.05)
# 2. Cohen's d
# 3. Boxplot
# --------------------------------------------------
# StatisticsTutor:
# 1. **Concept Explanation:**
#    The goal of this analysis is to compare the two sections (A and B) using statistical methods. We will conduct an independent t-test to evaluate if there's a significant difference in the means of the two sections at a significance level (alpha) of 0.05. Cohen's d will be calculated to determine the effect size, which indicates how large the difference between the groups is in standard deviation units. Finally, we will create a boxplot to visually represent the distributions of the scores in both sections.
#
# 2. **Python Code:**
# ```python
# import numpy as np
# import scipy.stats as stats
# import matplotlib.pyplot as plt
#
# # Scores of each section
# section_A = np.array([72, 85, 90, 68, 77, 95, 82, 78, 88, 74])
# section_B = np.array([65, 70, 88, 92, 76, 81, 69, 83, 79, 95])
#
# # 1. Statistical Significance Test (Independent t-test)
# t_stat, p_value = stats.ttest_ind(section_A, section_B)
# alpha = 0.05
# significance = p_value < alpha
#
# # 2. Cohen's d
# mean_A = np.mean(section_A)
# mean_B = np.mean(section_B)
# std_A = np.std(section_A, ddof=1)  # Sample standard deviation
# std_B = np.std(section_B, ddof=1)
#
# pooled_std = np.sqrt(((len(section_A) - 1) * std_A**2 + (len(section_B) - 1) * std_B**2) / (len(section_A) + len(section_B) - 2))
# cohens_d = (mean_A - mean_B) / pooled_std
#
# # 3. Boxplot
# plt.boxplot([section_A, section_B], labels=['Section A', 'Section B'])
# plt.title('Boxplot of Scores in Sections A and B')
# plt.ylabel('Scores')
# plt.show()
#
# # Print results
# print(f"T-statistic: {t_stat:.2f}, P-value: {p_value:.4f}, Significance: {significance}")
# print(f"Cohen's d: {cohens_d:.2f}")
# ```
#
# 3. **Interpret Results:**
# - The t-statistic and p-value provide information about the significance of the difference in means between the two sections. If the p-value is less than 0.05, we reject the null hypothesis and conclude there's a significant difference in means. The `significance` variable will be `True` if the p-value is below this threshold.
# - Cohen's d quantifies the effect size. A value of 0.2 is considered small, 0.5 medium, and 0.8 large. This helps in understanding how practically significant the difference is between the two groups.
# - The boxplot visually compares the distributions of scores in the two sections, highlighting differences in medians, quartiles, and potential outliers.
#
# TERMINATE.
# --------------------------------------------------
# CodeExecutor:
# [FunctionCall(id='call_FY8f8TYXTyuHkS2pDF8dHuhY', arguments='{"code": "import numpy as np\\nimport scipy.stats as stats\\nimport matplotlib.pyplot as plt\\n\\n# Scores of each section\\nsection_A = np.array([72, 85, 90, 68, 77, 95, 82, 78, 88, 74])\\nsection_B = np.array([65, 70, 88, 92, 76, 81, 69, 83, 79, 95])\\n\\n# 1. Statistical Significance Test (Independent t-test)\\nt_stat, p_value = stats.ttest_ind(section_A, section_B)\\nalpha = 0.05\\nsignificance = p_value < alpha\\n\\n# 2. Cohen\'s d\\nmean_A = np.mean(section_A)\\nmean_B = np.mean(section_B)\\nstd_A = np.std(section_A, ddof=1)  # Sample standard deviation\\nstd_B = np.std(section_B, ddof=1)\\n\\npooled_std = np.sqrt(((len(section_A) - 1) * std_A**2 + (len(section_B) - 1) * std_B**2) / (len(section_A) + len(section_B) - 2))\\ncohens_d = (mean_A - mean_B) / pooled_std\\n\\n# Print results\\nresults = f\\"T-statistic: {t_stat:.2f}, P-value: {p_value:.4f}, Significance: {significance}\\\\nCohen\'s d: {cohens_d:.2f}\\"\\nresults"}', name='CodeExecutor'), FunctionCall(id='call_P3Oyoqw9fTrVhVwm6K05RwYR', arguments='{"code": "import numpy as np\\nimport matplotlib.pyplot as plt\\n\\n# Scores of each section\\nsection_A = np.array([72, 85, 90, 68, 77, 95, 82, 78, 88, 74])\\nsection_B = np.array([65, 70, 88, 92, 76, 81, 69, 83, 79, 95])\\n\\n# 3. Boxplot\\nplt.boxplot([section_A, section_B], labels=[\'Section A\', \'Section B\'])\\nplt.title(\'Boxplot of Scores in Sections A and B\')\\nplt.ylabel(\'Scores\')\\nplt.show()"}', name='CodeExecutor')]
# --------------------------------------------------
# CodeExecutor:
# [FunctionExecutionResult(content='', name='CodeExecutor', call_id='call_FY8f8TYXTyuHkS2pDF8dHuhY', is_error=False), FunctionExecutionResult(content="/content/autogen_workspace/tmp_code_67dc013fe83261e6e0098502b64ea596fc081357738fd59ffcee7277a6d8c61a.py:9: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.\n  plt.boxplot([section_A, section_B], labels=['Section A', 'Section B'])\nFigure(640x480)\n", name='CodeExecutor', call_id='call_P3Oyoqw9fTrVhVwm6K05RwYR', is_error=False)]
# --------------------------------------------------
# CodeExecutor:
#
# /content/autogen_workspace/tmp_code_67dc013fe83261e6e0098502b64ea596fc081357738fd59ffcee7277a6d8c61a.py:9: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([section_A, section_B], labels=['Section A', 'Section B'])
# Figure(640x480)
#
# --------------------------------------------------
# StatisticsTutor:
# The warning message indicates that the `labels` parameter in the `plt.boxplot()` function has been deprecated and should be replaced with `tick_labels`. To resolve this and improve code compatibility with future versions of Matplotlib, I will update the code accordingly.
#
# Here's the revised Python code:
#
# ```python
# import numpy as np
# import scipy.stats as stats
# import matplotlib.pyplot as plt
#
# # Scores of each section
# section_A = np.array([72, 85, 90, 68, 77, 95, 82, 78, 88, 74])
# section_B = np.array([65, 70, 88, 92, 76, 81, 69, 83, 79, 95])
#
# # 1. Statistical Significance Test (Independent t-test)
# t_stat, p_value = stats.ttest_ind(section_A, section_B)
# alpha = 0.05
# significance = p_value < alpha
#
# # 2. Cohen's d
# mean_A = np.mean(section_A)
# mean_B = np.mean(section_B)
# std_A = np.std(section_A, ddof=1)  # Sample standard deviation
# std_B = np.std(section_B, ddof=1)
#
# pooled_std = np.sqrt(((len(section_A) - 1) * std_A**2 + (len(section_B) - 1) * std_B**2) / (len(section_A) + len(section_B) - 2))
# cohens_d = (mean_A - mean_B) / pooled_std
#
# # 3. Boxplot
# plt.boxplot([section_A, section_B], tick_label=['Section A', 'Section B'])
# plt.title('Boxplot of Scores in Sections A and B')
# plt.ylabel('Scores')
# plt.show()
#
# # Print results
# print(f"T-statistic: {t_stat:.2f}, P-value: {p_value:.4f}, Significance: {significance}")
# print(f"Cohen's d: {cohens_d:.2f}")
# ```
#
# ### Results Interpretation:
# Once you run the updated code:
# - The **T-statistic** and **P-value** will provide insight on whether there is a statistically significant difference in the mean scores of the two sections. A **P-value** less than 0.05 will indicate significant difference.
# - **Cohen's d** quantifies the effect size of the mean difference; values will categorize the difference into small, medium, or large effects.
# - The **Boxplot** will visually compare the score distributions, helping to identify differences in medians and variability along with potential outliers.
#
# TERMINATE.
# --------------------------------------------------
# CodeExecutor:
# [FunctionCall(id='call_kcBqC3guWeQF5SvECLca5PyC', arguments='{"code":"import numpy as np\\nimport scipy.stats as stats\\nimport matplotlib.pyplot as plt\\n\\n# Scores of each section\\nsection_A = np.array([72, 85, 90, 68, 77, 95, 82, 78, 88, 74])\\nsection_B = np.array([65, 70, 88, 92, 76, 81, 69, 83, 79, 95])\\n\\n# 1. Statistical Significance Test (Independent t-test)\\nt_stat, p_value = stats.ttest_ind(section_A, section_B)\\nalpha = 0.05\\nsignificance = p_value < alpha\\n\\n# 2. Cohen\'s d\\nmean_A = np.mean(section_A)\\nmean_B = np.mean(section_B)\\nstd_A = np.std(section_A, ddof=1)  # Sample standard deviation\\nstd_B = np.std(section_B, ddof=1)\\n\\npooled_std = np.sqrt(((len(section_A) - 1) * std_A**2 + (len(section_B) - 1) * std_B**2) / (len(section_A) + len(section_B) - 2))\\ncohens_d = (mean_A - mean_B) / pooled_std\\n\\n# 3. Boxplot\\nplt.boxplot([section_A, section_B], tick_label=[\'Section A\', \'Section B\'])\\nplt.title(\'Boxplot of Scores in Sections A and B\')\\nplt.ylabel(\'Scores\')\\nplt.show()\\n\\n# Print results\\nresults = f\\"T-statistic: {t_stat:.2f}, P-value: {p_value:.4f}, Significance: {significance}\\\\nCohen\'s d: {cohens_d:.2f}\\"  \\nresults"}', name='CodeExecutor')]
# --------------------------------------------------
# CodeExecutor:
# [FunctionExecutionResult(content='Traceback (most recent call last):\n  File "/content/autogen_workspace/tmp_code_96a900dfa7b920e2fd4551750fa88265cedafd5342503cd316c8027214b1719d.py", line 24, in <module>\n    plt.boxplot([section_A, section_B], tick_label=[\'Section A\', \'Section B\'])\n  File "/usr/local/lib/python3.12/dist-packages/matplotlib/_api/deprecation.py", line 453, in wrapper\n    return func(*args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/matplotlib/_api/deprecation.py", line 295, in wrapper\n    return func(*args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^\nTypeError: boxplot() got an unexpected keyword argument \'tick_label\'\n', name='CodeExecutor', call_id='call_kcBqC3guWeQF5SvECLca5PyC', is_error=False)]
# --------------------------------------------------
# CodeExecutor:
# Traceback (most recent call last):
#   File "/content/autogen_workspace/tmp_code_96a900dfa7b920e2fd4551750fa88265cedafd5342503cd316c8027214b1719d.py", line 24, in <module>
#     plt.boxplot([section_A, section_B], tick_label=['Section A', 'Section B'])
#   File "/usr/local/lib/python3.12/dist-packages/matplotlib/_api/deprecation.py", line 453, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/matplotlib/_api/deprecation.py", line 295, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
# TypeError: boxplot() got an unexpected keyword argument 'tick_label'
#
# --------------------------------------------------
# StatisticsTutor:
# It appears there was a misunderstanding in the naming convention for the parameters in the boxplot function. The correct parameter name is `tick_labels`, not `tick_label`. I apologize for the confusion.
#
# Here’s the corrected code:
#
# ```python
# import numpy as np
# import scipy.stats as stats
# import matplotlib.pyplot as plt
#
# # Scores of each section
# section_A = np.array([72, 85, 90, 68, 77, 95, 82, 78, 88, 74])
# section_B = np.array([65, 70, 88, 92, 76, 81, 69, 83, 79, 95])
#
# # 1. Statistical Significance Test (Independent t-test)
# t_stat, p_value = stats.ttest_ind(section_A, section_B)
# alpha = 0.05
# significance = p_value < alpha
#
# # 2. Cohen's d
# mean_A = np.mean(section_A)
# mean_B = np.mean(section_B)
# std_A = np.std(section_A, ddof=1)  # Sample standard deviation
# std_B = np.std(section_B, ddof=1)
#
# pooled_std = np.sqrt(((len(section_A) - 1) * std_A**2 + (len(section_B) - 1) * std_B**2) / (len(section_A) + len(section_B) - 2))
# cohens_d = (mean_A - mean_B) / pooled_std
#
# # 3. Boxplot
# plt.boxplot([section_A, section_B], tick_labels=['Section A', 'Section B'])
# plt.title('Boxplot of Scores in Sections A and B')
# plt.ylabel('Scores')
# plt.show()
#
# # Print results
# print(f"T-statistic: {t_stat:.2f}, P-value: {p_value:.4f}, Significance: {significance}")
# print(f"Cohen's d: {cohens_d:.2f}")
# ```
#
# ### Explanation:
# - The `tick_labels` parameter specifies the labels for the x-axis categories of the boxplot correctly now.
#
# ### Results Interpretation:
# When you successfully run this code, you'll obtain results regarding the statistical significance of the difference in scores between sections A and B, as well as the visual comparison via the boxplot.
#
# TERMINATE.
# --------------------------------------------------
# CodeExecutor:
# [FunctionCall(id='call_C3vhqSd94k929RsCesVs8jbx', arguments='{"code":"import numpy as np\\nimport scipy.stats as stats\\nimport matplotlib.pyplot as plt\\n\\n# Scores of each section\\nsection_A = np.array([72, 85, 90, 68, 77, 95, 82, 78, 88, 74])\\nsection_B = np.array([65, 70, 88, 92, 76, 81, 69, 83, 79, 95])\\n\\n# 1. Statistical Significance Test (Independent t-test)\\nt_stat, p_value = stats.ttest_ind(section_A, section_B)\\nalpha = 0.05\\nsignificance = p_value < alpha\\n\\n# 2. Cohen\'s d\\nmean_A = np.mean(section_A)\\nmean_B = np.mean(section_B)\\nstd_A = np.std(section_A, ddof=1)  # Sample standard deviation\\nstd_B = np.std(section_B, ddof=1)\\n\\npooled_std = np.sqrt(((len(section_A) - 1) * std_A**2 + (len(section_B) - 1) * std_B**2) / (len(section_A) + len(section_B) - 2))\\ncohens_d = (mean_A - mean_B) / pooled_std\\n\\n# 3. Boxplot\\nplt.boxplot([section_A, section_B], tick_labels=[\'Section A\', \'Section B\'])\\nplt.title(\'Boxplot of Scores in Sections A and B\')\\nplt.ylabel(\'Scores\')\\nplt.show()\\n\\n# Print results\\nresults = f\\"T-statistic: {t_stat:.2f}, P-value: {p_value:.4f}, Significance: {significance}\\\\nCohen\'s d: {cohens_d:.2f}\\"  \\nresults"}', name='CodeExecutor')]
# --------------------------------------------------
# CodeExecutor:
# [FunctionExecutionResult(content='Figure(640x480)\n', name='CodeExecutor', call_id='call_C3vhqSd94k929RsCesVs8jbx', is_error=False)]
# --------------------------------------------------
# CodeExecutor:
# Figure(640x480)
#
# --------------------------------------------------
# StatisticsTutor:
# It seems that the code executed successfully and generated the boxplot without any errors. Below is a detailed interpretation of the results that you would expect to see after running the code:
#
# 1. **T-statistic and P-value:**
#    - The `T-statistic` will indicate the magnitude of the difference between the means of the two sections relative to the variation in the sample data.
#    - The `P-value` will help determine if this difference is statistically significant.
#      - If the `P-value` is less than 0.05 (the alpha threshold), you reject the null hypothesis, concluding that there is a statistically significant difference in scores between Section A and Section B.
#
# 2. **Significance:**
#    - The `significance` variable will be `True` if the P-value is below 0.05, indicating significant differences.
#
# 3. **Cohen's d:**
#    - This value represents the effect size of the difference between the two sections.
#      - A Cohen's d value:
#        - Less than 0.2 signifies a small effect size.
#        - Around 0.5 indicates a medium effect size.
#        - Greater than 0.8 shows a large effect size.
#    - This helps in understanding how meaningful the difference is in practical terms, beyond just statistical significance.
#
# 4. **Boxplot:**
#    - The boxplot visually compares the distributions of scores in Sections A and B.
#    - It highlights the median scores, the interquartile ranges (IQR), and any potential outliers.
#    - You can directly observe differences in central tendency (medians) and variability between the two sections.
#
# ### Conclusion:
# - If you find a statistically significant result (low P-value) along with a meaningful Cohen's d, it suggests that the difference in scores between Sections A and B is not only statistically significant but also has practical relevance.
# - The boxplot provides a visual summary of these results for a clearer understanding of the comparative scores.
#
# If you have any specific outcomes from the code execution or need further analysis or clarification on any part, please let me know!
#
# TERMINATE.
# --------------------------------------------------
# CodeExecutor:
# T-statistic: 2.28, P-value: 0.0355, Significance: True
# Cohen's d: 0.52
# --------------------------------------------------

# %% [markdown]
# ---
# ## 9. Implementation 4 — Automated Data Analysis Pipeline
#
# **Scenario:** A data analyst agent writes code to analyze a sales dataset, produces statistics and a chart, and a reporter agent writes an executive summary of the findings.

# %%
import pandas as pd
import os

# Create workspace
os.makedirs("./autogen_workspace", exist_ok=True)

# Create dataset
sales_data = pd.DataFrame({
    "month": ["Jan", "Feb", "Mar", "Apr", "May", "Jun",
              "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"],
    "revenue": [420000, 385000, 510000, 490000, 610000, 580000,
                540000, 620000, 700000, 680000, 810000, 950000],
    "units_sold": [1200, 1050, 1480, 1390, 1720, 1680,
                   1540, 1790, 2010, 1950, 2340, 2680],
    "region": ["North", "North", "South", "South", "East", "East",
               "West", "West", "North", "South", "East", "West"],
    "customer_satisfaction": [4.2, 4.0, 4.5, 4.3, 4.6, 4.4,
                             4.1, 4.7, 4.8, 4.5, 4.9, 4.8],
})

# Save CSV
file_path = "./autogen_workspace/sales_2023.csv"
sales_data.to_csv(file_path, index=False)

print(f"✅ Sample dataset created at {file_path}\n")
print(sales_data.head())
# Out:
# ✅ Sample dataset created at ./autogen_workspace/sales_2023.csv
#
#   month  revenue  units_sold region  customer_satisfaction
# 0   Jan   420000        1200  North                    4.2
# 1   Feb   385000        1050  North                    4.0
# 2   Mar   510000        1480  South                    4.5
# 3   Apr   490000        1390  South                    4.3
# 4   May   610000        1720   East                    4.6

# %%
# ================================
# INSTALL (run once)
# ================================
# !pip install pyautogen autogen-ext[openai] autogen-ext[code] asyncio-atexit --upgrade


# ================================
# IMPORTS
# ================================
import os
from google.colab import userdata

from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_ext.models.openai import OpenAIChatCompletionClient
from autogen_ext.code_executors.local import LocalCommandLineCodeExecutor
from autogen_ext.tools.code_execution import PythonCodeExecutionTool


# ================================
# MODEL CLIENT
# ================================
api_key = userdata.get("OPENAI_API_KEY")

model_client = OpenAIChatCompletionClient(
    model="gpt-4o-mini",
    api_key=api_key,
)


# ================================
# EXECUTION TOOL
# ================================
executor_backend = LocalCommandLineCodeExecutor(
    work_dir="./autogen_workspace",
    timeout=60,
)

code_tool = PythonCodeExecutionTool(
    executor=executor_backend
)


# ================================
# AGENTS
# ================================

# --- Data Analyst ---
data_analyst = AssistantAgent(
    name="DataAnalyst",
    system_message=(
        "You are a senior data analyst.\n"
        "1. Load CSV\n"
        "2. Compute requested metrics\n"
        "3. Provide 3 key insights\n"
        "4. Generate chart and save PNG\n"
        "Use pandas, matplotlib, seaborn.\n"
        "Wrap code in ONE python block.\n"
        "End with ANALYSIS COMPLETE."
    ),
    model_client=model_client,
)

# --- Code Executor ---
executor_agent = AssistantAgent(
    name="CodeExecutor",
    system_message=(
        "Execute Python code from previous message. "
        "Return ONLY output. Do not explain."
    ),
    model_client=model_client,
    tools=[code_tool],
)

# --- Reporter ---
reporter = AssistantAgent(
    name="ExecutiveReporter",
    system_message=(
        "You are a business intelligence writer.\n"
        "Write under 300 words:\n"
        "Overview (2 sentences)\n"
        "Key Findings (3 bullets with numbers)\n"
        "Recommendations (2 actions)\n"
        "End with TERMINATE."
    ),
    model_client=model_client,
)


# ================================
# TEAM (PIPELINE FLOW)
# ================================
team = RoundRobinGroupChat(
    participants=[data_analyst, executor_agent, reporter],
    max_turns=8,
)


# ================================
# TASK
# ================================
task = (
    "Analyze dataset at ./autogen_workspace/sales_2023.csv\n\n"
    "Compute:\n"
    "1. Total revenue and units\n"
    "2. Month-over-month revenue growth\n"
    "3. Revenue by region\n"
    "4. Correlation between satisfaction and revenue\n\n"
    "Save chart as monthly_revenue.png\n\n"
    "Then produce executive summary."
)


# ================================
# RUN (Colab-safe)
# ================================
result = await team.run(task=task)

print("\n✅ Pipeline complete\n")

for msg in result.messages:
    print(f"{msg.source}:")
    print(msg.content)
    print("-" * 50)
# Out:
# Requirement already satisfied: pyautogen in /usr/local/lib/python3.12/dist-packages (0.10.0)
# Requirement already satisfied: asyncio-atexit in /usr/local/lib/python3.12/dist-packages (1.0.1)
# Requirement already satisfied: autogen-ext[openai] in /usr/local/lib/python3.12/dist-packages (0.7.5)
# Requirement already satisfied: autogen-agentchat>=0.6.4 in /usr/local/lib/python3.12/dist-packages (from pyautogen) (0.7.5)
# Requirement already satisfied: autogen-core==0.7.5 in /usr/local/lib/python3.12/dist-packages (from autogen-ext[openai]) (0.7.5)
# Requirement already satisfied: aiofiles in /usr/local/lib/python3.12/dist-packages (from autogen-ext[openai]) (24.1.0)
# Requirement already satisfied: openai>=1.93 in /usr/local/lib/python3.12/dist-packages (from autogen-ext[openai]) (2.34.0)
# Requirement already satisfied: tiktoken>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from autogen-ext[openai]) (0.12.0)
# Requirement already satisfied: jsonref~=1.1.0 in /usr/local/lib/python3.12/dist-packages (from autogen-core==0.7.5->autogen-ext[openai]) (1.1.0)
# Requirement already satisfied: opentelemetry-api>=1.34.1 in /usr/local/lib/python3.12/dist-packages (from autogen-core==0.7.5->autogen-ext[openai]) (1.41.1)
# Requirement already satisfied: pillow>=11.0.0 in /usr/local/lib/python3.12/dist-packages (from autogen-core==0.7.5->autogen-ext[openai]) (11.3.0)
# Requirement already satisfied: protobuf~=5.29.3 in /usr/local/lib/python3.12/dist-packages (from autogen-core==0.7.5->autogen-ext[openai]) (5.29.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.10.0 in /usr/local/lib/python3.12/dist-packages (from autogen-core==0.7.5->autogen-ext[openai]) (2.12.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from autogen-core==0.7.5->autogen-ext[openai]) (4.15.0)
# WARNING: autogen-ext 0.7.5 does not provide the extra 'code'
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.93->autogen-ext[openai]) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.93->autogen-ext[openai]) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.93->autogen-ext[openai]) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.93->autogen-ext[openai]) (0.14.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai>=1.93->autogen-ext[openai]) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai>=1.93->autogen-ext[openai]) (4.67.3)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken>=0.8.0->autogen-ext[openai]) (2025.11.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from tiktoken>=0.8.0->autogen-ext[openai]) (2.32.4)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai>=1.93->autogen-ext[openai]) (3.13)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai>=1.93->autogen-ext[openai]) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai>=1.93->autogen-ext[openai]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.93->autogen-ext[openai]) (0.16.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-api>=1.34.1->autogen-core==0.7.5->autogen-ext[openai]) (8.7.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.7.5->autogen-ext[openai]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.7.5->autogen-ext[openai]) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.7.5->autogen-ext[openai]) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken>=0.8.0->autogen-ext[openai]) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken>=0.8.0->autogen-ext[openai]) (2.5.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.34.1->autogen-core==0.7.5->autogen-ext[openai]) (3.23.1)
# /tmp/ipykernel_10701/1067575186.py:34: UserWarning: Using LocalCommandLineCodeExecutor may execute code on the local machine which can be unsafe. For security, it is recommended to use DockerCommandLineCodeExecutor instead. To install Docker, visit: https://docs.docker.com/get-docker/
#   executor_backend = LocalCommandLineCodeExecutor(
# ✅ Pipeline complete
#
# user:
# Analyze dataset at ./autogen_workspace/sales_2023.csv
#
# Compute:
# 1. Total revenue and units
# 2. Month-over-month revenue growth
# 3. Revenue by region
# 4. Correlation between satisfaction and revenue
#
# Save chart as monthly_revenue.png
#
# Then produce executive summary.
# --------------------------------------------------
# DataAnalyst:
# ```python
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# # Load the CSV
# file_path = './autogen_workspace/sales_2023.csv'
# data = pd.read_csv(file_path)
#
# # Convert date to datetime
# data['date'] = pd.to_datetime(data['date'])
#
# # Compute Total Revenue and Units
# total_revenue = data['revenue'].sum()
# total_units = data['units_sold'].sum()
#
# # Compute Month-over-Month Revenue Growth
# data['month'] = data['date'].dt.to_period('M')
# monthly_revenue = data.groupby('month')['revenue'].sum().reset_index()
# monthly_revenue['month_growth'] = monthly_revenue['revenue'].pct_change() * 100
#
# # Compute Revenue by Region
# revenue_by_region = data.groupby('region')['revenue'].sum().reset_index()
#
# # Compute Correlation between Satisfaction and Revenue
# correlation = data['satisfaction'].corr(data['revenue'])
#
# # Generate Chart for Monthly Revenue
# plt.figure(figsize=(10, 6))
# sns.lineplot(data=monthly_revenue, x='month', y='revenue', marker='o')
# plt.title('Monthly Revenue for 2023')
# plt.xlabel('Month')
# plt.ylabel('Revenue')
# plt.xticks(rotation=45)
# plt.tight_layout()
# plt.savefig('monthly_revenue.png')
#
# # Key Insights
# key_insights = {
#     "total_revenue": total_revenue,
#     "total_units": total_units,
#     "revenue_by_region": revenue_by_region,
#     "month_over_month_growth": monthly_revenue[['month', 'month_growth']],
#     "satisfaction_revenue_correlation": correlation
# }
#
# # Executive summary
# executive_summary = f"""
# Executive Summary:
# 1. The total revenue generated in 2023 is ${total_revenue:.2f} and a total of {total_units} units were sold.
# 2. The month-over-month revenue growth indicates fluctuations in sales performance, with the highest growth observed in the month of {monthly_revenue['month'][monthly_revenue['month_growth'].idxmax()]} at {monthly_revenue['month_growth'].max():.2f}%.
# 3. Revenue by region analysis shows significant variances, with the following regions contributing the most:
# {revenue_by_region.to_string(index=False)}.
# 4. The correlation between customer satisfaction and revenue is {correlation:.2f}, indicating a positive relationship where higher satisfaction levels may correlate with increased revenue.
#
# This analysis provides insights into sales performance trends, regional revenue contributions, and customer satisfaction impact, which can inform strategic decision-making for future initiatives.
# """
#
# print(executive_summary)
# ```
#
# ANALYSIS COMPLETE.
# --------------------------------------------------
# CodeExecutor:
# [FunctionCall(id='call_pYsg7FgACAbFP9SGCiXEkOaA', arguments='{"code":"import pandas as pd\\nimport matplotlib.pyplot as plt\\nimport seaborn as sns\\n\\n# Load the CSV\\nfile_path = \'./autogen_workspace/sales_2023.csv\'\\ndata = pd.read_csv(file_path)\\n\\n# Convert date to datetime\\ndata[\'date\'] = pd.to_datetime(data[\'date\'])\\n\\n# Compute Total Revenue and Units\\ntotal_revenue = data[\'revenue\'].sum()\\ntotal_units = data[\'units_sold\'].sum()\\n\\n# Compute Month-over-Month Revenue Growth\\ndata[\'month\'] = data[\'date\'].dt.to_period(\'M\')\\nmonthly_revenue = data.groupby(\'month\')[\'revenue\'].sum().reset_index()\\nmonthly_revenue[\'month_growth\'] = monthly_revenue[\'revenue\'].pct_change() * 100\\n\\n# Compute Revenue by Region\\nrevenue_by_region = data.groupby(\'region\')[\'revenue\'].sum().reset_index()\\n\\n# Compute Correlation between Satisfaction and Revenue\\ncorrelation = data[\'satisfaction\'].corr(data[\'revenue\'])\\n\\n# Generate Chart for Monthly Revenue\\nplt.figure(figsize=(10, 6))\\nsns.lineplot(data=monthly_revenue, x=\'month\', y=\'revenue\', marker=\'o\')\\nplt.title(\'Monthly Revenue for 2023\')\\nplt.xlabel(\'Month\')\\nplt.ylabel(\'Revenue\')\\nplt.xticks(rotation=45)\\nplt.tight_layout()\\nplt.savefig(\'monthly_revenue.png\')\\n\\n# Key Insights\\nkey_insights = {\\n    \\"total_revenue\\": total_revenue,\\n    \\"total_units\\": total_units,\\n    \\"revenue_by_region\\": revenue_by_region,\\n    \\"month_over_month_growth\\": monthly_revenue[[\'month\', \'month_growth\']],\\n    \\"satisfaction_revenue_correlation\\": correlation\\n}\\n\\n# Executive summary\\nexecutive_summary = f\\"\\"\\"\\nExecutive Summary:\\n1. The total revenue generated in 2023 is ${total_revenue:.2f} and a total of {total_units} units were sold.\\n2. The month-over-month revenue growth indicates fluctuations in sales performance, with the highest growth observed in the month of {monthly_revenue[\'month\'][monthly_revenue[\'month_growth\'].idxmax()]} at {monthly_revenue[\'month_growth\'].max():.2f}%. \\n3. Revenue by region analysis shows significant variances, with the following regions contributing the most: \\n{revenue_by_region.to_string(index=False)}.\\n4. The correlation between customer satisfaction and revenue is {correlation:.2f}, indicating a positive relationship where higher satisfaction levels may correlate with increased revenue.\\n\\nThis analysis provides insights into sales performance trends, regional revenue contributions, and customer satisfaction impact, which can inform strategic decision-making for future initiatives.\\n\\"\\"\\"\\n\\nprint(executive_summary)"}', name='CodeExecutor')]
# --------------------------------------------------
# CodeExecutor:
# [FunctionExecutionResult(content='Traceback (most recent call last):\n  File "/content/autogen_workspace/tmp_code_f3c54e9813da12163b6fb2c705d3330c65f63959cb3b473c0020753d2a0f0d8b.py", line 7, in <module>\n    data = pd.read_csv(file_path)\n           ^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py", line 1026, in read_csv\n    return _read(filepath_or_buffer, kwds)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py", line 620, in _read\n    parser = TextFileReader(filepath_or_buffer, **kwds)\n             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py", line 1620, in __init__\n    self._engine = self._make_engine(f, self.engine)\n                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py", line 1880, in _make_engine\n    self.handles = get_handle(\n                   ^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/pandas/io/common.py", line 873, in get_handle\n    handle = open(\n             ^^^^^\nFileNotFoundError: [Errno 2] No such file or directory: \'./autogen_workspace/sales_2023.csv\'\n', name='CodeExecutor', call_id='call_pYsg7FgACAbFP9SGCiXEkOaA', is_error=False)]
# --------------------------------------------------
# CodeExecutor:
# Traceback (most recent call last):
#   File "/content/autogen_workspace/tmp_code_f3c54e9813da12163b6fb2c705d3330c65f63959cb3b473c0020753d2a0f0d8b.py", line 7, in <module>
#     data = pd.read_csv(file_path)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py", line 1026, in read_csv
#     return _read(filepath_or_buffer, kwds)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py", line 620, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py", line 1620, in __init__
#     self._engine = self._make_engine(f, self.engine)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py", line 1880, in _make_engine
#     self.handles = get_handle(
#                    ^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/io/common.py", line 873, in get_handle
#     handle = open(
#              ^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: './autogen_workspace/sales_2023.csv'
#
# --------------------------------------------------
# ExecutiveReporter:
# It appears that the specified file path `./autogen_workspace/sales_2023.csv` does not exist, leading to a `FileNotFoundError`. Please ensure that the file is correctly uploaded to the right directory before running the analysis.
#
# In the meantime, based on the expected analysis of a sales dataset, here's an executive summary template that you could use once the analysis is complete:
#
# ---
#
# **Executive Summary:**
# 1. The total revenue generated in 2023 is ${total_revenue:.2f} with a total of {total_units} units sold.
# 2. Month-over-month revenue growth indicates fluctuations in sales performance, with the highest growth observed in the month of {highest_growth_month} at {highest_growth_percentage:.2f}%.
# 3. Revenue by region reveals significant variances, with key contributions from the following areas:
#    - {region_1}: ${revenue_region_1}
#    - {region_2}: ${revenue_region_2}
#    - {region_3}: ${revenue_region_3}
# 4. The correlation between customer satisfaction and revenue stands at {correlation_value:.2f}, indicating a strong positive relationship.
#
# This analysis presents key insights into sales trends, regional contributions, and customer satisfaction impacts, which can support strategic decisions moving forward.
#
# ---
#
# Feel free to fill in the placeholders with the actual computed values once the dataset is accessible and analyzed.
#
# TERMINATE.
# --------------------------------------------------
# DataAnalyst:
# It seems that the dataset path mentioned does not lead to an existing file. Please ensure that the data file is correctly uploaded to the specified location before executing the analysis again.
#
# Once you have the dataset ready, you can run the following code to perform the analysis and create the executive summary based on the computed metrics.
#
# Here’s the code for reference:
#
# ```python
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# # Load the CSV
# file_path = './autogen_workspace/sales_2023.csv'
# data = pd.read_csv(file_path)
#
# # Convert date to datetime
# data['date'] = pd.to_datetime(data['date'])
#
# # Compute Total Revenue and Units
# total_revenue = data['revenue'].sum()
# total_units = data['units_sold'].sum()
#
# # Compute Month-over-Month Revenue Growth
# data['month'] = data['date'].dt.to_period('M')
# monthly_revenue = data.groupby('month')['revenue'].sum().reset_index()
# monthly_revenue['month_growth'] = monthly_revenue['revenue'].pct_change() * 100
#
# # Compute Revenue by Region
# revenue_by_region = data.groupby('region')['revenue'].sum().reset_index()
#
# # Compute Correlation between Satisfaction and Revenue
# correlation = data['satisfaction'].corr(data['revenue'])
#
# # Generate Chart for Monthly Revenue
# plt.figure(figsize=(10, 6))
# sns.lineplot(data=monthly_revenue, x='month', y='revenue', marker='o')
# plt.title('Monthly Revenue for 2023')
# plt.xlabel('Month')
# plt.ylabel('Revenue')
# plt.xticks(rotation=45)
# plt.tight_layout()
# plt.savefig('monthly_revenue.png')
#
# # Key Insights
# key_insights = {
#     "total_revenue": total_revenue,
#     "total_units": total_units,
#     "revenue_by_region": revenue_by_region,
#     "month_over_month_growth": monthly_revenue[['month', 'month_growth']],
#     "satisfaction_revenue_correlation": correlation
# }
#
# # Executive summary
# executive_summary = f"""
# Executive Summary:
# 1. The total revenue generated in 2023 is ${total_revenue:.2f} and a total of {total_units} units were sold.
# 2. The month-over-month revenue growth indicates fluctuations in sales performance, with the highest growth observed in the month of {monthly_revenue['month'][monthly_revenue['month_growth'].idxmax()]} at {monthly_revenue['month_growth'].max():.2f}%.
# 3. Revenue by region analysis shows significant variances, with the following regions contributing the most:
# {revenue_by_region.to_string(index=False)}.
# 4. The correlation between customer satisfaction and revenue is {correlation:.2f}, indicating a positive relationship where higher satisfaction levels may correlate with increased revenue.
#
# This analysis provides insights into sales performance trends, regional revenue contributions, and customer satisfaction impact, which can inform strategic decision-making for future initiatives.
# """
#
# print(executive_summary)
# ```
#
# Once the analysis is successfully executed, you will have the insights and executive summary needed.
#
# If further assistance is required, feel free to ask.
#
# ANALYSIS COMPLETE.
# --------------------------------------------------
# CodeExecutor:
# **Executive Summary:**
# 1. The total revenue generated in 2023 is ${total_revenue:.2f} with a total of {total_units} units sold.
# 2. Month-over-month revenue growth indicates fluctuations in sales performance, with the highest growth observed in the month of {highest_growth_month} at {highest_growth_percentage:.2f}%.
# 3. Revenue by region reveals significant variances, with key contributions from the following areas:
#    - {region_1}: ${revenue_region_1}
#    - {region_2}: ${revenue_region_2}
#    - {region_3}: ${revenue_region_3}
# 4. The correlation between customer satisfaction and revenue stands at {correlation_value:.2f}, indicating a strong positive relationship.
#
# This analysis presents key insights into sales trends, regional contributions, and customer satisfaction impacts, which can support strategic decisions moving forward.
# --------------------------------------------------
# ExecutiveReporter:
# It seems like the executive summary template provided is not populated with actual data values. Once you have successfully run the analysis with the dataset, those placeholders will need to be replaced with computed metrics from the analysis. Here’s how you can format the summary with actual data once available:
#
# ---
#
# **Executive Summary:**
# 1. The total revenue generated in 2023 is **$[actual_total_revenue]** with a total of **[actual_total_units]** units sold.
# 2. Month-over-month revenue growth indicates fluctuations in sales performance, with the highest growth observed in the month of **[month_of_highest_growth]** at **[highest_growth_percentage]%**.
# 3. Revenue by region reveals significant variances, with key contributions from the following areas:
#    - **[region_1]**: **$[revenue_region_1]**
#    - **[region_2]**: **$[revenue_region_2]**
#    - **[region_3]**: **$[revenue_region_3]**
# 4. The correlation between customer satisfaction and revenue stands at **[correlation_value]**, indicating a strong positive relationship.
#
# This analysis provides key insights into sales trends, regional contributions, and the impact of customer satisfaction, which can support strategic decisions moving forward.
#
# ---
#
# Once you have access to the dataset and can execute the analysis, replace the placeholders with the respective computed values to finalize the executive summary.
#
# If you need help with anything else or want to execute the analysis again, let me know!
#
# TERMINATE.
# --------------------------------------------------
# DataAnalyst:
# It appears that the executive summary template has not been populated with actual data values. Once the analysis is successfully performed on the dataset, the placeholders in the summary need to be replaced with the computed metrics.
#
# Below is a structured guide on how to format your executive summary with actual data when it becomes available:
#
# ---
#
# **Executive Summary:**
# 1. The total revenue generated in 2023 is **$[actual_total_revenue]** with a total of **[actual_total_units]** units sold.
# 2. Month-over-month revenue growth indicates fluctuations in sales performance, with the highest growth observed in the month of **[month_of_highest_growth]** at **[highest_growth_percentage]%**.
# 3. Revenue by region reveals significant variances, with key contributions from the following areas:
#    - **[region_1]**: **$[revenue_region_1]**
#    - **[region_2]**: **$[revenue_region_2]**
#    - **[region_3]**: **$[revenue_region_3]**
# 4. The correlation between customer satisfaction and revenue stands at **[correlation_value]**, indicating a strong positive relationship.
#
# This analysis provides key insights into sales trends, regional contributions, and the impact of customer satisfaction, which can support strategic decisions moving forward.
#
# ---
#
# Once the dataset is accessible and the analysis is completed, you can replace the placeholders with the relevant metrics derived from your analysis.
#
# Should you need further assistance or want to attempt executing the analysis again, please let me know!
#
# TERMINATE.
# --------------------------------------------------
# CodeExecutor:
# **Executive Summary:**
# 1. The total revenue generated in 2023 is **$[actual_total_revenue]** with a total of **[actual_total_units]** units sold.
# 2. Month-over-month revenue growth indicates fluctuations in sales performance, with the highest growth observed in the month of **[month_of_highest_growth]** at **[highest_growth_percentage]%**.
# 3. Revenue by region reveals significant variances, with key contributions from the following areas:
#    - **[region_1]**: **$[revenue_region_1]**
#    - **[region_2]**: **$[revenue_region_2]**
#    - **[region_3]**: **$[revenue_region_3]**
# 4. The correlation between customer satisfaction and revenue stands at **[correlation_value]**, indicating a strong positive relationship.
#
# This analysis provides key insights into sales trends, regional contributions, and customer satisfaction impacts, which can support strategic decisions moving forward.
# --------------------------------------------------

# %% [markdown]
# ---
# ## 10
# . Advanced: Tool / Function Calling
#
# AutoGen supports OpenAI-style function calling. You register functions on the agent and they are called when the LLM decides to use them.

# %%
# ================================
# INSTALL (run once)
# ================================
# !pip install pyautogen autogen-ext[openai] --upgrade


# ================================
# IMPORTS
# ================================
from datetime import datetime
from google.colab import userdata

from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_ext.models.openai import OpenAIChatCompletionClient


# ================================
# TOOL FUNCTIONS
# ================================
def get_current_stock_price(ticker: str) -> dict:
    mock_prices = {
        "AAPL": {"price": 189.42, "change_pct": 0.82, "volume": "52.3M"},
        "MSFT": {"price": 415.20, "change_pct": -0.31, "volume": "18.9M"},
        "GOOGL": {"price": 178.65, "change_pct": 1.24, "volume": "21.1M"},
        "NVDA": {"price": 875.30, "change_pct": 2.15, "volume": "41.7M"},
    }
    data = mock_prices.get(ticker.upper(), {"error": f"Ticker {ticker} not found"})
    return {"ticker": ticker.upper(), "timestamp": datetime.now().isoformat(), **data}


def calculate_portfolio_value(holdings: list) -> dict:
    mock_prices = {"AAPL": 189.42, "MSFT": 415.20, "GOOGL": 178.65, "NVDA": 875.30}
    total = 0.0
    breakdown = []

    for h in holdings:
        ticker = h["ticker"].upper()
        shares = h["shares"]
        price = mock_prices.get(ticker, 0)
        value = price * shares
        total += value

        breakdown.append({
            "ticker": ticker,
            "shares": shares,
            "price": price,
            "value": round(value, 2)
        })

    return {
        "total_value": round(total, 2),
        "breakdown": breakdown
    }


# ================================
# MODEL CLIENT
# ================================
api_key = userdata.get("OPENAI_API_KEY")

model_client = OpenAIChatCompletionClient(
    model="gpt-4o-mini",
    api_key=api_key,
)


# ================================
# AGENT WITH TOOLS (NEW WAY)
# ================================
portfolio_advisor = AssistantAgent(
    name="PortfolioAdvisor",
    system_message=(
        "You are a portfolio advisor.\n"
        "Use tools to fetch stock prices and calculate portfolio value.\n"
        "Show calculations clearly.\n"
        "End with TERMINATE."
    ),
    model_client=model_client,
    tools=[get_current_stock_price, calculate_portfolio_value],  # ✅ direct functions
)


# ================================
# TEAM (single-agent loop)
# ================================
team = RoundRobinGroupChat(
    participants=[portfolio_advisor],
    max_turns=5,
)


# ================================
# TASK
# ================================
task = (
    "I hold:\n"
    "- 50 shares of AAPL\n"
    "- 30 shares of MSFT\n"
    "- 15 shares of NVDA\n\n"
    "1. Get current price for each\n"
    "2. Calculate total portfolio value\n"
    "3. Identify largest holding percentage"
)


# ================================
# RUN (Colab-safe)
# ================================
result = await team.run(task=task)

print("\n✅ Done\n")

for msg in result.messages:
    print(f"{msg.source}:")
    print(msg.content)
    print("-" * 50)
# Out:
# Requirement already satisfied: pyautogen in /usr/local/lib/python3.12/dist-packages (0.10.0)
# Requirement already satisfied: autogen-ext[openai] in /usr/local/lib/python3.12/dist-packages (0.7.5)
# Requirement already satisfied: autogen-agentchat>=0.6.4 in /usr/local/lib/python3.12/dist-packages (from pyautogen) (0.7.5)
# Requirement already satisfied: autogen-core==0.7.5 in /usr/local/lib/python3.12/dist-packages (from autogen-ext[openai]) (0.7.5)
# Requirement already satisfied: aiofiles in /usr/local/lib/python3.12/dist-packages (from autogen-ext[openai]) (24.1.0)
# Requirement already satisfied: openai>=1.93 in /usr/local/lib/python3.12/dist-packages (from autogen-ext[openai]) (2.34.0)
# Requirement already satisfied: tiktoken>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from autogen-ext[openai]) (0.12.0)
# Requirement already satisfied: jsonref~=1.1.0 in /usr/local/lib/python3.12/dist-packages (from autogen-core==0.7.5->autogen-ext[openai]) (1.1.0)
# Requirement already satisfied: opentelemetry-api>=1.34.1 in /usr/local/lib/python3.12/dist-packages (from autogen-core==0.7.5->autogen-ext[openai]) (1.41.1)
# Requirement already satisfied: pillow>=11.0.0 in /usr/local/lib/python3.12/dist-packages (from autogen-core==0.7.5->autogen-ext[openai]) (11.3.0)
# Requirement already satisfied: protobuf~=5.29.3 in /usr/local/lib/python3.12/dist-packages (from autogen-core==0.7.5->autogen-ext[openai]) (5.29.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.10.0 in /usr/local/lib/python3.12/dist-packages (from autogen-core==0.7.5->autogen-ext[openai]) (2.12.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from autogen-core==0.7.5->autogen-ext[openai]) (4.15.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.93->autogen-ext[openai]) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.93->autogen-ext[openai]) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.93->autogen-ext[openai]) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.93->autogen-ext[openai]) (0.14.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai>=1.93->autogen-ext[openai]) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai>=1.93->autogen-ext[openai]) (4.67.3)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken>=0.8.0->autogen-ext[openai]) (2025.11.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from tiktoken>=0.8.0->autogen-ext[openai]) (2.32.4)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai>=1.93->autogen-ext[openai]) (3.13)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai>=1.93->autogen-ext[openai]) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai>=1.93->autogen-ext[openai]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.93->autogen-ext[openai]) (0.16.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-api>=1.34.1->autogen-core==0.7.5->autogen-ext[openai]) (8.7.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.7.5->autogen-ext[openai]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.7.5->autogen-ext[openai]) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.7.5->autogen-ext[openai]) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken>=0.8.0->autogen-ext[openai]) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken>=0.8.0->autogen-ext[openai]) (2.5.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.34.1->autogen-core==0.7.5->autogen-ext[openai]) (3.23.1)
#
# ✅ Done
#
# user:
# I hold:
# - 50 shares of AAPL
# - 30 shares of MSFT
# - 15 shares of NVDA
#
# 1. Get current price for each
# 2. Calculate total portfolio value
# 3. Identify largest holding percentage
# --------------------------------------------------
# PortfolioAdvisor:
# [FunctionCall(id='call_tz3ky5BmvrOzNzhwmJ2DxEoW', arguments='{"ticker": "AAPL"}', name='get_current_stock_price'), FunctionCall(id='call_SVVcxBGMN0TlsHz0BoFApXij', arguments='{"ticker": "MSFT"}', name='get_current_stock_price'), FunctionCall(id='call_6VpZh9ZhRMmLmYUZXGxyHbUX', arguments='{"ticker": "NVDA"}', name='get_current_stock_price')]
# --------------------------------------------------
# PortfolioAdvisor:
# [FunctionExecutionResult(content="{'ticker': 'AAPL', 'timestamp': '2026-05-05T09:29:35.981161', 'price': 189.42, 'change_pct': 0.82, 'volume': '52.3M'}", name='get_current_stock_price', call_id='call_tz3ky5BmvrOzNzhwmJ2DxEoW', is_error=False), FunctionExecutionResult(content="{'ticker': 'MSFT', 'timestamp': '2026-05-05T09:29:35.981240', 'price': 415.2, 'change_pct': -0.31, 'volume': '18.9M'}", name='get_current_stock_price', call_id='call_SVVcxBGMN0TlsHz0BoFApXij', is_error=False), FunctionExecutionResult(content="{'ticker': 'NVDA', 'timestamp': '2026-05-05T09:29:35.981662', 'price': 875.3, 'change_pct': 2.15, 'volume': '41.7M'}", name='get_current_stock_price', call_id='call_6VpZh9ZhRMmLmYUZXGxyHbUX', is_error=False)]
# --------------------------------------------------
# PortfolioAdvisor:
# {'ticker': 'AAPL', 'timestamp': '2026-05-05T09:29:35.981161', 'price': 189.42, 'change_pct': 0.82, 'volume': '52.3M'}
# {'ticker': 'MSFT', 'timestamp': '2026-05-05T09:29:35.981240', 'price': 415.2, 'change_pct': -0.31, 'volume': '18.9M'}
# {'ticker': 'NVDA', 'timestamp': '2026-05-05T09:29:35.981662', 'price': 875.3, 'change_pct': 2.15, 'volume': '41.7M'}
# --------------------------------------------------
# PortfolioAdvisor:
# [FunctionCall(id='call_h0YzqG4HCC9cKRve6B5olPOw', arguments='{"holdings":[{"ticker":"AAPL","shares":50,"price":189.42},{"ticker":"MSFT","shares":30,"price":415.2},{"ticker":"NVDA","shares":15,"price":875.3}]}', name='calculate_portfolio_value')]
# --------------------------------------------------
# PortfolioAdvisor:
# [FunctionExecutionResult(content="{'total_value': 35056.5, 'breakdown': [{'ticker': 'AAPL', 'shares': 50, 'price': 189.42, 'value': 9471.0}, {'ticker': 'MSFT', 'shares': 30, 'price': 415.2, 'value': 12456.0}, {'ticker': 'NVDA', 'shares': 15, 'price': 875.3, 'value': 13129.5}]}", name='calculate_portfolio_value', call_id='call_h0YzqG4HCC9cKRve6B5olPOw', is_error=False)]
# --------------------------------------------------
# PortfolioAdvisor:
# {'total_value': 35056.5, 'breakdown': [{'ticker': 'AAPL', 'shares': 50, 'price': 189.42, 'value': 9471.0}, {'ticker': 'MSFT', 'shares': 30, 'price': 415.2, 'value': 12456.0}, {'ticker': 'NVDA', 'shares': 15, 'price': 875.3, 'value': 13129.5}]}
# --------------------------------------------------
# PortfolioAdvisor:
# Here are the details of your portfolio:
#
# ### Current Stock Prices:
# - **AAPL** (Apple): $189.42
# - **MSFT** (Microsoft): $415.2
# - **NVDA** (NVIDIA): $875.3
#
# ### Portfolio Breakdown:
# 1. **AAPL**:
#    - Shares: 50
#    - Price per share: $189.42
#    - Total Value: $9,471.00
#
# 2. **MSFT**:
#    - Shares: 30
#    - Price per share: $415.20
#    - Total Value: $12,456.00
#
# 3. **NVDA**:
#    - Shares: 15
#    - Price per share: $875.30
#    - Total Value: $13,129.50
#
# ### Total Portfolio Value:
# - The total value of your portfolio is **$35,056.50**.
#
# ### Largest Holding Percentage:
# - **AAPL**: \( \frac{9471.0}{35056.5} \times 100 \approx 26.98\% \)
# - **MSFT**: \( \frac{12456.0}{35056.5} \times 100 \approx 35.49\% \)
# - **NVDA**: \( \frac{13129.5}{35056.5} \times 100 \approx 37.53\% \)
#
# The largest holding in your portfolio is **NVDA** (NVIDIA) at approximately **37.53%**.
#
# TERMINATE
# --------------------------------------------------
# PortfolioAdvisor:
# Here are the details of your portfolio:
#
# ### Current Stock Prices:
# - **AAPL** (Apple): $189.42
# - **MSFT** (Microsoft): $415.2
# - **NVDA** (NVIDIA): $875.3
#
# ### Portfolio Breakdown:
# 1. **AAPL**:
#    - Shares: 50
#    - Price per share: $189.42
#    - Total Value: $9,471.00
#
# 2. **MSFT**:
#    - Shares: 30
#    - Price per share: $415.20
#    - Total Value: $12,456.00
#
# 3. **NVDA**:
#    - Shares: 15
#    - Price per share: $875.30
#    - Total Value: $13,129.50
#
# ### Total Portfolio Value:
# - The total value of your portfolio is **$35,056.50**.
#
# ### Largest Holding Percentage:
# - **AAPL**: \( \frac{9471.0}{35056.5} \times 100 \approx 26.98\% \)
# - **MSFT**: \( \frac{12456.0}{35056.5} \times 100 \approx 35.49\% \)
# - **NVDA**: \( \frac{13129.5}{35056.5} \times 100 \approx 37.53\% \)
#
# The largest holding in your portfolio is **NVDA** (NVIDIA) at approximately **37.53%**.
#
# TERMINATE
# --------------------------------------------------
# PortfolioAdvisor:
# Here are the details of your portfolio:
#
# ### Current Stock Prices:
# - **AAPL** (Apple): $189.42
# - **MSFT** (Microsoft): $415.20
# - **NVDA** (NVIDIA): $875.30
#
# ### Portfolio Breakdown:
# 1. **AAPL**:
#    - Shares: 50
#    - Price per share: $189.42
#    - Total Value: $9,471.00
#
# 2. **MSFT**:
#    - Shares: 30
#    - Price per share: $415.20
#    - Total Value: $12,456.00
#
# 3. **NVDA**:
#    - Shares: 15
#    - Price per share: $875.30
#    - Total Value: $13,129.50
#
# ### Total Portfolio Value:
# - The total value of your portfolio is **$35,056.50**.
#
# ### Largest Holding Percentage:
# - **AAPL**: \( \frac{9471.0}{35056.5} \times 100 \approx 26.98\% \)
# - **MSFT**: \( \frac{12456.0}{35056.5} \times 100 \approx 35.49\% \)
# - **NVDA**: \( \frac{13129.5}{35056.5} \times 100 \approx 37.53\% \)
#
# The largest holding in your portfolio is **NVDA** (NVIDIA) at approximately **37.53%**.
#
# TERMINATE
# --------------------------------------------------

# %% [markdown]
# ---
# ## 12. Advanced: Nested Chats
#
# Nested chats allow an agent to spawn a private sub-conversation with other agents and return the result to the parent conversation — useful for modular reasoning.

# %%
# ================================
# INSTALL (run once)
# ================================
# !pip install pyautogen autogen-ext[openai] --upgrade


# ================================
# IMPORTS
# ================================
from google.colab import userdata

from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_ext.models.openai import OpenAIChatCompletionClient


# ================================
# MODEL CLIENT
# ================================
api_key = userdata.get("OPENAI_API_KEY")

model_client = OpenAIChatCompletionClient(
    model="gpt-4o-mini",
    api_key=api_key,
)


# ================================
# AGENTS
# ================================

# --- Financial Specialist ---
financial_modeler = AssistantAgent(
    name="FinancialModeler",
    system_message=(
        "You are a financial modeling specialist.\n"
        "Compute:\n"
        "- Break-even units\n"
        "- Gross margin\n"
        "- 12-month revenue projection\n"
        "Return results in a structured table.\n"
        "End with MODEL COMPLETE."
    ),
    model_client=model_client,
)

# --- Business Consultant ---
business_consultant = AssistantAgent(
    name="BusinessConsultant",
    system_message=(
        "You are a business consultant.\n"
        "When solving a pricing problem:\n"
        "1. First consult FinancialModeler\n"
        "2. Use its output\n"
        "3. Provide final recommendation\n"
        "Only return the final business answer (not raw model details).\n"
        "End with TERMINATE."
    ),
    model_client=model_client,
)

from autogen_agentchat.conditions import TextMentionTermination
# ================================
# TEAM (simulates nested flow)
# ================================
team = RoundRobinGroupChat(
    participants=[financial_modeler, business_consultant],
    termination_condition=termination,
    max_turns=4,
)


# ================================
# TASK
# ================================
task = (
    "Client request:\n"
    "SaaS pricing scenario:\n"
    "- Cost per customer: $12/month\n"
    "- Price: $49/month\n"
    "- Growth: 10 customers → 200 customers in 12 months\n\n"
    "Provide pricing evaluation and financial outlook."
)


# ================================
# RUN (Colab-safe)
# ================================
result = await team.run(task=task)

print("\n✅ Done\n")

for msg in result.messages:
    print(f"{msg.source}:")
    print(msg.content)
    print("-" * 50)
# Out:
# ✅ Done
#
# user:
# Client request:
# SaaS pricing scenario:
# - Cost per customer: $12/month
# - Price: $49/month
# - Growth: 10 customers → 200 customers in 12 months
#
# Provide pricing evaluation and financial outlook.
# --------------------------------------------------
# FinancialModeler:
# To analyze the SaaS pricing scenario, we will compute the following:
#
# 1. Break-even units
# 2. Gross margin
# 3. 12-month revenue projection
#
# **Assumptions:**
# - Cost per customer (Variable Cost) = $12/month
# - Price per customer (Revenue) = $49/month
# - Growth from 10 customers to 200 customers over 12 months.
#
# ### Financial Calculations
#
# 1. **Break-even Units**
#    - Break-even Point (BEP) = Fixed Costs / (Price per unit - Variable Cost per unit)
#    - Since we do not have fixed costs explicitly mentioned, we will assume it to be zero for this calculation. Under normal circumstances, fixed costs would need to be provided for an accurate break-even analysis.
#
#    \( BEP = \frac{Fixed Costs}{Price - Cost} \) (assuming Fixed Costs = 0)
#
# 2. **Gross Margin**
#    - Gross Margin = (Price - Variable Cost) / Price
#    - Gross Margin (in percentage) = \( \frac{49 - 12}{49} \)
#
# 3. **12-month Revenue Projection**
#    - Revenue = Number of Customers * Price per Customer * 12 months
#    - We'll calculate the projection by assuming a linear growth from 10 to 200 customers over the 12 months.
#
# ### Structured Table of Results
#
# | Metric                             | Value                                   |
# |------------------------------------|-----------------------------------------|
# | Break-even Units                   | N/A (Insufficient data on Fixed Costs) |
# | Gross Margin                       | 75.51% (approx.)                       |
# | Total Revenue for 12 months        | $1,175,400                              |
#
# ### Revenue Calculation Breakdown:
# - Initial Customers: 10, Final Customers: 200
# - Average Customers Over 12 months: \( \frac{10 + 200}{2} \) = 105 customers
# - Total Revenue: \( 105 \text{ customers} \times 49 \text{ (price)} \times 12 \text{ (months)} = 61,560 \) (for the first month)
# - Total Revenue across the year with growth considered = ($12,000 + $2,352,000) = $1,175,400.
#
# ### Conclusion
# Based on the provided data and calculations:
# - **Break-even Units:** N/A (requires fixed cost data).
# - **Gross Margin:** 75.51%
# - **12-month Revenue Projection:** $1,175,400
#
# **MODEL COMPLETE**
# --------------------------------------------------
# BusinessConsultant:
# Based on the financial evaluation of your SaaS pricing scenario:
#
# - **Gross Margin:** 75.51%
# - **12-month Revenue Projection:** $1,175,400
#
# It is recommended to maintain the pricing at $49/month due to a strong gross margin. This pricing not only covers the variable costs but also provides a substantial profit margin as you scale from 10 to 200 customers over 12 months. Consider monitoring customer feedback and market trends regularly to ensure that your pricing remains competitive and reflective of the service's value.
#
# TERMINATE.
# --------------------------------------------------
# FinancialModeler:
# Thank you for your feedback. Should you need further analysis or assistance in the future, feel free to reach out.
#
# **MODEL COMPLETE**
# --------------------------------------------------
# BusinessConsultant:
# You're welcome! If you need any further assistance or analysis in the future, don't hesitate to ask. Have a great day!
#
# TERMINATE.
# --------------------------------------------------

# %% [markdown]
# ---
# ## 13. Advanced: Human Proxy with Termination Conditions

# %%
# ================================
# INSTALL (run once)
# ================================
# !pip install pyautogen autogen-ext[openai] --upgrade


# ================================
# IMPORTS
# ================================
from google.colab import userdata

from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_ext.models.openai import OpenAIChatCompletionClient


# ================================
# MODEL CLIENT
# ================================
api_key = userdata.get("OPENAI_API_KEY")

model_client = OpenAIChatCompletionClient(
    model="gpt-4o-mini",
    api_key=api_key,
)


# ================================
# AGENT
# ================================
ai_drafter = AssistantAgent(
    name="ContractDrafter",
    system_message=(
        "You draft professional business contracts.\n"
        "After completing, end with: DRAFT COMPLETE."
    ),
    model_client=model_client,
)


# ================================
# TEAM (single agent loop)
# ================================
team = RoundRobinGroupChat(
    participants=[ai_drafter],
    max_turns=3,
)


# ================================
# STEP 1: GENERATE DRAFT
# ================================
task = (
    "Draft a one-page NDA between Acme Corp (disclosing party) "
    "and a freelance consultant (receiving party). "
    "Include: confidential info definition, obligations, exclusions, "
    "2-year term, New York law."
)

result = await team.run(task=task)

print("\n📄 AI Draft:\n")

final_msg = result.messages[-1].content
print(final_msg)


# ================================
# STEP 2: HUMAN REVIEW (MANUAL)
# ================================
if "DRAFT COMPLETE" in final_msg:
    print("\n🧑‍⚖️ Review required.")
    feedback = input("Enter feedback (or type 'approve'): ")

    if feedback.lower() != "approve":
        # ================================
        # STEP 3: REVISE BASED ON FEEDBACK
        # ================================
        revision_task = (
            f"Revise the NDA based on this feedback:\n{feedback}"
        )

        revision_result = await team.run(task=revision_task)

        print("\n📄 Revised Draft:\n")
        print(revision_result.messages[-1].content)

    else:
        print("\n✅ Draft approved.")
# Out:
# 📄 AI Draft:
#
# **NON-DISCLOSURE AGREEMENT**
#
# This Non-Disclosure Agreement ("Agreement") is entered into as of this ___ day of ______, 2023, by and between Acme Corp, a corporation organized under the laws of New York with a principal place of business at [Insert Address] ("Disclosing Party"), and [Consultant's Name], an independent freelance consultant with a principal place of business at [Insert Address] ("Receiving Party").
#
# **1. Definition of Confidential Information**
# For purposes of this Agreement, "Confidential Information" shall include any and all non-public information, data, materials, or knowledge disclosed by Disclosing Party to Receiving Party, whether in written, oral, electronic, or any other form, that is identified as confidential or should reasonably be understood to be confidential under the circumstances of disclosure, including but not limited to business plans, customer information, product specifications, and financial data.
#
# **2. Obligations of Receiving Party**
# Receiving Party agrees to:
# (a) Maintain the confidentiality of the Confidential Information and take all reasonable measures to protect it;
# (b) Not disclose any Confidential Information to third parties without the prior written consent of Disclosing Party;
# (c) Use the Confidential Information solely for the purpose of evaluating or performing work for Disclosing Party;
# (d) Return or destroy all Confidential Information upon the request of Disclosing Party at the conclusion of the engagement or the termination of this Agreement.
#
# **3. Exclusions**
# Confidential Information does not include information that:
# (a) Was publicly available at the time of disclosure or becomes publicly available through no fault of Receiving Party;
# (b) Was in the possession of Receiving Party prior to disclosure by Disclosing Party;
# (c) Is received by Receiving Party from a third party without a breach of any obligation of confidentiality;
# (d) Is independently developed by Receiving Party without use of or reference to the Confidential Information.
#
# **4. Term**
# The obligations of Receiving Party with respect to Confidential Information shall survive for a period of two (2) years from the date of disclosure.
#
# **5. Governing Law**
# This Agreement shall be governed by and construed in accordance with the laws of the State of New York, without regard to its conflict of laws principles.
#
# IN WITNESS WHEREOF, the parties hereto have executed this Non-Disclosure Agreement as of the date first above written.
#
# _________________________
# [Disclosing Party - Acme Corp]
# By: _______________________
# Name: _____________________
# Title: ______________________
#
# _________________________
# [Receiving Party - Consultant]
# By: _______________________
# Name: _____________________
# Title: ______________________
#
# DRAFT COMPLETE.
#
# 🧑‍⚖️ Review required.
# Enter feedback (or type 'approve'): Approve
#
# ✅ Draft approved.

# %% [markdown]
# ---
# ## 14. Advanced: Custom Reply Functions
#
# You can intercept the normal reply process and inject custom logic using `register_reply`.

# %%
# ================================
# IMPORTS
# ================================
from datetime import datetime
from google.colab import userdata

from autogen_agentchat.agents import AssistantAgent
from autogen_ext.models.openai import OpenAIChatCompletionClient


# ================================
# MODEL CLIENT
# ================================
api_key = userdata.get("OPENAI_API_KEY")

model_client = OpenAIChatCompletionClient(
    model="gpt-4o-mini",
    api_key=api_key,
)


# ================================
# MIDDLEWARE FUNCTIONS
# ================================
def log_message(message: str, sender: str, recipient: str):
    timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    print(f"[LOG {timestamp}] {sender} → {recipient}")
    print(f"[LOG] Preview: {message[:100]}...\n")


def validate_input(message: str):
    disallowed = ["competitor_secret", "internal_pricing_db"]
    for keyword in disallowed:
        if keyword in message.lower():
            return False, f"Blocked due to restricted keyword: {keyword}"
    return True, None


# ================================
# AGENT
# ================================
agent = AssistantAgent(
    name="MonitoredAssistant",
    system_message="""
You are a helpful assistant.
Always answer the user's question clearly and completely.
End every response with TERMINATE.
""",
    model_client=model_client,
)


# ================================
# SAFE RUN WRAPPER
# ================================
async def safe_run(user_input: str):
    # --- validation ---
    is_valid, error = validate_input(user_input)
    if not is_valid:
        print(error)
        return

    # --- logging input ---
    log_message(user_input, "User", "Agent")

    # --- run agent directly (FIXED) ---
    result = await agent.run(task=user_input)

    final_msg = result.messages[-1].content

    # --- logging output ---
    log_message(final_msg, "Agent", "User")

    print("Response:\n")
    print(final_msg)


# ================================
# RUN
# ================================
await safe_run("What are three best practices for writing maintainable Python code?")
# Out:
# [LOG 2026-05-05 10:02:08] User → Agent
# [LOG] Preview: What are three best practices for writing maintainable Python code?...
#
# [LOG 2026-05-05 10:02:16] Agent → User
# [LOG] Preview: Here are three best practices for writing maintainable Python code:
#
# 1. **Follow PEP 8 Guidelines**:...
#
# Response:
#
# Here are three best practices for writing maintainable Python code:
#
# 1. **Follow PEP 8 Guidelines**: Adhering to the PEP 8 style guide for Python code helps maintain consistency and readability. This includes using proper naming conventions for variables and functions, ensuring code is properly indented, and structuring imports cleanly. Tools like `flake8` or `black` can help enforce these guidelines automatically.
#
# 2. **Use Clear and Descriptive Names**: Choose variable, function, and class names that clearly indicate their purpose. This makes the code easier to understand and maintain. For example, instead of naming a variable `x`, use a name like `user_count` if it represents the number of users.
#
# 3. **Write Modular and Reusable Code**: Break down your code into small, reusable functions or classes. This not only promotes code reuse but also makes it easier to test and debug. Each function should aim to perform a single task (following the Single Responsibility Principle). This modularity facilitates updates and collaboration.
#
# Following these practices will enhance the maintainability of your Python code, making it easier for you and others to work with it over time.
#
# TERMINATE

# %%
# !pip install -U "autogen-ext[openai]"
# Out:
# Collecting autogen-ext[openai]
#   Downloading autogen_ext-0.7.5-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: autogen-core==0.7.5 in /usr/local/lib/python3.12/dist-packages (from autogen-ext[openai]) (0.7.5)
# Requirement already satisfied: aiofiles in /usr/local/lib/python3.12/dist-packages (from autogen-ext[openai]) (25.1.0)
# Requirement already satisfied: openai>=1.93 in /usr/local/lib/python3.12/dist-packages (from autogen-ext[openai]) (2.43.0)
# Requirement already satisfied: tiktoken>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from autogen-ext[openai]) (0.13.0)
# Requirement already satisfied: jsonref~=1.1.0 in /usr/local/lib/python3.12/dist-packages (from autogen-core==0.7.5->autogen-ext[openai]) (1.1.0)
# Requirement already satisfied: opentelemetry-api>=1.34.1 in /usr/local/lib/python3.12/dist-packages (from autogen-core==0.7.5->autogen-ext[openai]) (1.43.0)
# Requirement already satisfied: pillow>=11.0.0 in /usr/local/lib/python3.12/dist-packages (from autogen-core==0.7.5->autogen-ext[openai]) (11.3.0)
# Requirement already satisfied: protobuf~=5.29.3 in /usr/local/lib/python3.12/dist-packages (from autogen-core==0.7.5->autogen-ext[openai]) (5.29.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.10.0 in /usr/local/lib/python3.12/dist-packages (from autogen-core==0.7.5->autogen-ext[openai]) (2.13.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from autogen-core==0.7.5->autogen-ext[openai]) (4.15.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.93->autogen-ext[openai]) (4.14.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.93->autogen-ext[openai]) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.93->autogen-ext[openai]) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.93->autogen-ext[openai]) (0.15.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai>=1.93->autogen-ext[openai]) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai>=1.93->autogen-ext[openai]) (4.67.3)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from tiktoken>=0.8.0->autogen-ext[openai]) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from tiktoken>=0.8.0->autogen-ext[openai]) (2.32.4)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai>=1.93->autogen-ext[openai]) (3.18)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai>=1.93->autogen-ext[openai]) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai>=1.93->autogen-ext[openai]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.93->autogen-ext[openai]) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.7.5->autogen-ext[openai]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.7.5->autogen-ext[openai]) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.7.5->autogen-ext[openai]) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->tiktoken>=0.8.0->autogen-ext[openai]) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->tiktoken>=0.8.0->autogen-ext[openai]) (2.5.0)
# Downloading autogen_ext-0.7.5-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.4/331.4 kB 3.6 MB/s eta 0:00:00
# Installing collected packages: autogen-ext
# Successfully installed autogen-ext-0.7.5

# %%
from autogen_ext.models.openai import OpenAIChatCompletionClient

# %%
import autogen_ext
print(autogen_ext.__version__)
# Out:
# 0.7.5

# %%
# ============================================
# INSTALL
# ============================================
# !pip install -U pyautogen autogen-ext[openai]

# ============================================
# IMPORTS
# ============================================
from google.colab import userdata

from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.conditions import TextMentionTermination
from autogen_agentchat.teams import SelectorGroupChat

from autogen_ext.models.openai import OpenAIChatCompletionClient

# ============================================
# MODEL
# ============================================
api_key = userdata.get("OPENAI_API_KEY")

model_client = OpenAIChatCompletionClient(
    model="gpt-4o-mini",
    api_key=api_key,
)

# ============================================
# AGENTS
# ============================================

researcher = AssistantAgent(
    name="Researcher",
    model_client=model_client,
    system_message="""
You are a market researcher.

Collect relevant facts and market insights.

Do NOT make recommendations.
""",
)

analyst = AssistantAgent(
    name="Analyst",
    model_client=model_client,
    system_message="""
You are a business analyst.

Use the research findings to perform SWOT analysis
and estimate risks.

Do NOT make final recommendations.
""",
)

advisor = AssistantAgent(
    name="Advisor",
    model_client=model_client,
    system_message="""
You are a senior business advisor.

Read everyone's work and provide the final recommendation.

End your response with TERMINATE.
""",
)

# ============================================
# TERMINATION
# ============================================

termination = TextMentionTermination("TERMINATE")

# ============================================
# SELECTOR GROUP CHAT
# ============================================

team = SelectorGroupChat(
    participants=[
        researcher,
        analyst,
        advisor,
    ],
    model_client=model_client,
    termination_condition=termination,
    max_turns=10,
)

# ============================================
# TASK
# ============================================

task = """
A startup wants to launch an AI-powered
resume screening platform.

Research the market,
analyze strengths and risks,
and provide a final recommendation.
"""

# ============================================
# RUN
# ============================================

result = await team.run(task=task)

print("\n========== FINAL CHAT ==========\n")

for msg in result.messages:
    print(f"{msg.source}:")
    print(msg.content)
    print("-" * 80)
# Out:
# ========== FINAL CHAT ==========
#
# user:
#
# A startup wants to launch an AI-powered
# resume screening platform.
#
# Research the market,
# analyze strengths and risks,
# and provide a final recommendation.
#
# --------------------------------------------------------------------------------
# Researcher:
# ### Market Research: AI-Powered Resume Screening Platform
#
# #### Market Insights
#
# 1. **Market Size and Growth**:
#    - The global AI recruitment market was valued at approximately $1.4 billion in 2020 and is expected to grow at a compound annual growth rate (CAGR) of around 7-10% through 2028.
#    - Increasing adoption of AI across various industries indicates a growing acceptance of technology in human resources (HR).
#
# 2. **Key Trends**:
#    - **Automation of HR Tasks**: Companies are increasingly looking to automate repetitive tasks such as resume screening to improve efficiency.
#    - **Diversity and Inclusion**: There's a growing need for AI solutions that mitigate bias in recruitment and promote diversity, leading to demand for ethical AI.
#    - **Integration with HR Systems**: Companies are interested in platforms that can easily integrate with existing Applicant Tracking Systems (ATS).
#
# 3. **Competitors**:
#    - Established players in the market include companies like HireVue, Pymetrics, and Jobvite.
#    - Many startups are emerging, focusing on niche markets or innovative features that leverage AI in recruitment.
#
# 4. **Target Audience**:
#    - HR departments of medium to large enterprises looking to streamline recruitment processes.
#    - Recruitment agencies seeking more efficient ways to manage candidate applications.
#
# 5. **Technology Trends**:
#    - Natural Language Processing (NLP) is commonly used to parse and analyze resumes.
#    - Machine Learning models are employed to continually improve screening accuracy by learning from past hiring data.
#
# #### Strengths
#
# 1. **Efficiency Improvement**: AI-powered platforms can sift through large volumes of resumes more quickly than human recruiters.
# 2. **Consistency**: AI systems can provide consistent evaluations without the subjectivity that may affect manual screening processes.
# 3. **Scalability**: Such platforms can easily scale to handle increased workload as companies grow or during peak recruitment periods.
# 4. **Data-Driven Insights**: AI systems can generate analytics and insights about the recruitment process that can help refine hiring strategies.
#
# #### Risks
#
# 1. **Bias in AI Algorithms**: If not properly managed, AI can perpetuate existing biases in hiring, which can lead to legal and reputational risks.
# 2. **Dependency on Quality Data**: AI performance heavily relies on the quality of data it’s trained on. Poor data can lead to ineffective screening.
# 3. **Resistance to Change**: HR professionals may be hesitant to adopt AI solutions due to fears of job loss or a lack of understanding of the technology.
# 4. **Regulatory Scrutiny**: As AI use in hiring grows, it is increasingly subject to regulation regarding fairness and accountability, which could impose constraints on operations.
#
# #### Conclusion
#
# The market for AI-powered resume screening platforms is characterized by significant growth potential, driven by the need for efficiency in recruitment and the increasing use of technology in HR processes. However, potential strengths like improved efficiency and data-driven insights must be balanced against risks such as algorithmic bias and regulatory challenges.
# --------------------------------------------------------------------------------
# Analyst:
# ### SWOT Analysis for AI-Powered Resume Screening Platform
#
# #### Strengths
# 1. **Efficiency Improvement**: The platform can process a high volume of resumes quickly, reducing the time-to-hire considerably for businesses.
# 2. **Consistency in Screening**: AI ensures a uniform evaluation of candidates, reducing subjective biases experienced in human evaluations.
# 3. **Scalability**: The platform can easily adapt to varying hiring volumes, whether during peak recruitment seasons or as a company grows.
# 4. **Data-Driven Insights**: Ability to provide analytics on candidate trends, which can improve recruitment strategies and tracking of hiring metrics.
#
# #### Weaknesses
# 1. **Initial Investment**: Development and integration of an AI-based system can require substantial upfront investment in technology and training.
# 2. **Complexity of Implementation**: Companies may face challenges in integrating AI systems with existing HR technologies, especially if those systems are outdated.
# 3. **User Training**: HR staff may require significant training to effectively utilize the platform and understand AI's output.
# 4. **Dependence on Data Quality**: The effectiveness of AI relies on high-quality training data; poor data can lead to inaccurate results.
#
# #### Opportunities
# 1. **Increasing Demand**: Continuous growth in the recruitment sector with a growing reliance on technology presents ample opportunities for market penetration.
# 2. **Focus on Diversity and Inclusion**: Developing features that target unbiased screening processes can capture market interest and meet current industry needs.
# 3. **Partnerships with Existing ATS Providers**: Collaborating with established Applicant Tracking Systems can enhance integration capabilities and widen market reach.
# 4. **Customization Options for Various Industries**: Creating tailored solutions for different sectors can open avenues into niche markets with specific recruitment needs.
#
# #### Threats
# 1. **Intense Competition**: The presence of both established companies and new startups introduces a high level of competition; differentiation may be challenging.
# 2. **Regulatory Environment**: Increasing scrutiny and regulations regarding AI in recruitment can lead to compliance challenges and potential legal repercussions.
# 3. **Technological Changes**: Rapid technological advancements may require continuous upgrades to the platform, leading to additional costs and resource allocation.
# 4. **Public Perception and Trust**: Growing concerns over AI fairness and transparency could affect the adoption of AI-based solutions if public trust is not gained.
#
# ### Risk Estimates
# - **Algorithmic Bias**: High-risk if not addressed; could lead to lawsuits, reputational damage, and loss of clientele.
# - **Data Quality Dependency**: Medium to high-risk; substantial effort needed to ensure data used for training is current and free of bias.
# - **Adoption Resistance**: Medium-risk; potential challenges in user acceptance could slow down integration and utilization of the platform.
# - **Regulatory Changes**: Medium-risk; evolving regulations could necessitate costly updates and compliance efforts.
#
# #### Conclusion
# The AI-powered resume screening platform has a solid foundation with considerable strengths and opportunities. However, it must navigate significant weaknesses and threats, especially concerning algorithmic bias and regulatory compliance. Careful consideration of the risks associated with implementation and market entry is crucial to success.
# --------------------------------------------------------------------------------
# Advisor:
# ### Final Recommendation
#
# After reviewing the market research and SWOT analysis for the AI-powered resume screening platform, the following considerations and recommendations are outlined:
#
# #### Key Conclusions
# 1. **Market Opportunity**: The recruitment sector is increasingly adopting AI solutions, boosting the growth potential for an AI-powered resume screening platform. The emphasis on efficiency, consistency, and data-driven insights aligns with the strategic needs of HR departments across various industries.
#
# 2. **Competitive Landscape**: There is significant competition, with established players and new entrants vying for market share. Differentiation will be crucial, particularly through features that enhance bias mitigation and support diversity initiatives.
#
# 3. **Risks and Challenges**: Notable risks include algorithmic bias, regulatory scrutiny, and the necessity for high-quality training data. Furthermore, there can be resistance from HR professionals in adapting to AI technologies that could be perceived as a threat to their roles.
#
# ### Strategic Recommendations
# 1. **Focus on Bias Mitigation**: Implement features that specifically address bias in hiring processes. Demonstrating a commitment to diversity and inclusion will not only enhance brand reputation but also resonate with many companies' missions and values.
#
# 2. **User-Centric Design and Training**: Prioritize intuitive user design for the platform to ease adoption challenges. Additionally, provide comprehensive training materials and support to equip HR professionals with the tools they need to effectively use the AI screening technology.
#
# 3. **Collaborative Partnerships**: Build partnerships with existing Applicant Tracking Systems (ATS) and HR platforms to facilitate integration, thus broadening the reach to potential clients who may already utilize these systems.
#
# 4. **Continuous Compliance Monitoring**: Establish a framework for ongoing monitoring of regulations and potential changes in the legal landscape related to AI use in recruitment, ensuring that the platform adapts proactively to meet compliance requirements.
#
# 5. **Investment in Data Quality**: Invest in robust data management practices to ensure the quality and relevance of the data utilized for training AI algorithms. This will mitigate risks related to data quality dependency and enhance the overall effectiveness of the platform.
#
# ### Conclusion
# Entering the AI-powered resume screening market presents a viable business opportunity, with evident strengths and opportunities to tap into a growing demand. However, careful navigation of identified risks and proactive strategies to enhance user adoption and regulatory compliance will be essential for success.
#
# I recommend moving forward with this venture, while assuring that all necessary precautions and strategies are put in place to mitigate inherent risks.
#
# TERMINATE
# --------------------------------------------------------------------------------

# %% [markdown]
# ---
# ## 15. Best Practices and Common Pitfalls
#
# ### Best Practices
#
# **Agent Design**
# - Always include a termination instruction in the `system_message` (e.g., "when complete, say TERMINATE"). Without it, conversations may run indefinitely.
# - Use specific, detailed `system_message` values. Generic instructions produce generic output.
# - Separate execution from reasoning: use `AssistantAgent` for LLM reasoning and `UserProxyAgent` for code execution. Mixing both in one agent creates unpredictable behavior.
#
# **Conversation Design**
# - Always set `max_consecutive_auto_reply` and `max_turns` as safety guards against runaway loops.
# - Use `is_termination_msg` with a specific, unambiguous trigger phrase. Avoid phrases that might appear naturally in text.
# - For `GroupChat`, keep agent count low (3-5). More agents increase LLM routing confusion and cost.
#
# **Code Execution**
# - Use `use_docker=True` in production environments to sandbox code execution safely.
# - Set `timeout` to prevent runaway code from blocking the conversation.
# - Use `last_n_messages` to control how far back the executor searches for code blocks.
#
# **RAG Configuration**
# - Use `chunk_token_size=300` to 500 for Q&A tasks. Larger chunks work better for code retrieval.
# - Set `get_or_create=True` to avoid re-indexing documents on every run.
# - Always pair `RetrieveUserProxyAgent` with `RetrieveAssistantAgent` — the proxy handles retrieval, the assistant handles generation.
#
# ### Common Pitfalls
#
# | Pitfall | Cause | Fix |
# |---|---|---|
# | Conversation never ends | No termination condition | Add `is_termination_msg` and TERMINATE in system prompt |
# | Code blocks not executed | `code_execution_config=False` on executor | Set `code_execution_config` with `work_dir` |
# | GroupChat loops on one agent | `speaker_selection_method="auto"` confused | Try `round_robin` or provide explicit selection hints in `system_message` |
# | Function call not triggered | Missing `tools` in `llm_config` | Add function schemas to `llm_config["tools"]` |
# | RAG retrieves wrong chunks | Chunk size too large or too small | Adjust `chunk_token_size` and `n_results` |
# | High token costs in GroupChat | Too many agents, too many rounds | Reduce `max_round` and number of agents |
